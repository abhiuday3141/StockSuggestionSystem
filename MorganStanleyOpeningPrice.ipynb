# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_datareader import data, wb
import datetime
import tensorflow as tf
from datetime import date, timedelta
# %matplotlib inline

# %%
start = datetime.datetime(2005, 1, 1)
end = datetime.datetime(2020, 1, 1)

# %%
bank="MS"
stocks = data.DataReader(bank, 'yahoo', start, end)

# %%
stocks.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2004-12-31  55.810001  55.209999  55.259998  55.520000  2449700.0  33.187542
# 2005-01-03  56.529999  55.709999  55.970001  55.900002  5105800.0  33.414707
# 2005-01-04  56.110001  54.759998  56.000000  55.299999  6100300.0  33.056053
# 2005-01-05  55.919998  54.980000  55.049999  54.980000  5072100.0  32.864769
# 2005-01-06  56.619999  55.770000  55.950001  56.279999  5991400.0  33.641857

# %%
plt.figure(figsize=(14,14))
plt.plot(stocks['Open'])
plt.title('Historical Stock Value')
plt.xlabel('Years')
plt.ylabel('Opening Stock Price')
# Out:
# Text(0, 0.5, 'Opening Stock Price')

# %%
df=stocks.reset_index()['Open']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
train_size=int(len(df)*0.70)
test_size=len(df)-train_size
train_data=df[0:train_size]
test_data=df[train_size:]

# %%
def make_dataset(data,timestep):
    X=[]
    y=[]
    n=len(data)
    for i in range(0,n-timestep-1):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X),np.array(y)

# %%
timestep=30
X_train,y_train=make_dataset(train_data,timestep)
X_test,y_test=make_dataset(test_data,timestep)
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(40,return_sequences=True,input_shape=(timestep,1)))
model.add(LSTM(40,return_sequences=True))
model.add(LSTM(40))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam') ##Stacked LSTM

# %%
import numpy as np
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional
from keras.datasets import imdb

# %%
modelBD = Sequential()
modelBD.add(Bidirectional(LSTM(64)))
modelBD.add(Dropout(0.5))
modelBD.add(Dense(1,activation='sigmoid'))
modelBD.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy']) ## Creating Bi-Directional LSTM

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 40)            6720
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 40)            12960
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 40)                12960
# _________________________________________________________________
# dense (Dense)                (None, 1)                 41
# =================================================================
# Total params: 32,681
# Trainable params: 32,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=70,batch_size=40,verbose=1)
# Out:
# Epoch 1/70
# 66/66 [==============================] - 14s 74ms/step - loss: 0.0218 - val_loss: 5.9037e-04
# Epoch 2/70
# 66/66 [==============================] - 3s 46ms/step - loss: 0.0010 - val_loss: 6.0072e-04
# Epoch 3/70
# 66/66 [==============================] - 3s 45ms/step - loss: 9.4124e-04 - val_loss: 5.9916e-04
# Epoch 4/70
# 66/66 [==============================] - 3s 51ms/step - loss: 9.5416e-04 - val_loss: 5.4815e-04
# Epoch 5/70
# 66/66 [==============================] - 3s 50ms/step - loss: 9.1966e-04 - val_loss: 6.5392e-04
# Epoch 6/70
# 66/66 [==============================] - 3s 50ms/step - loss: 8.4847e-04 - val_loss: 6.1184e-04
# Epoch 7/70
# 66/66 [==============================] - 3s 44ms/step - loss: 8.4004e-04 - val_loss: 4.2827e-04
# Epoch 8/70
# 66/66 [==============================] - 3s 46ms/step - loss: 7.2729e-04 - val_loss: 5.6759e-04
# Epoch 9/70
# 66/66 [==============================] - 3s 43ms/step - loss: 7.1666e-04 - val_loss: 6.9353e-04
# Epoch 10/70
# 66/66 [==============================] - 3s 46ms/step - loss: 7.0988e-04 - val_loss: 4.0024e-04
# Epoch 11/70
# 66/66 [==============================] - 3s 47ms/step - loss: 6.3690e-04 - val_loss: 3.5873e-04
# Epoch 67/70
# 66/66 [==============================] - 3s 52ms/step - loss: 1.9039e-04 - val_loss: 7.7650e-05
# Epoch 68/70
# 66/66 [==============================] - 3s 52ms/step - loss: 2.2030e-04 - val_loss: 7.8631e-05
# Epoch 69/70
# 66/66 [==============================] - 3s 51ms/step - loss: 2.0692e-04 - val_loss: 2.7593e-04
# Epoch 70/70
# 66/66 [==============================] - 4s 54ms/step - loss: 2.2133e-04 - val_loss: 7.9402e-05

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
train_predict
# Out:
# array([[58.87956 ],
#        [60.53381 ],
#        [60.25473 ],
#        ...,
#        [39.89773 ],
#        [39.58159 ],
#        [38.999466]], dtype=float32)

# %%
test_predict
# Out:
# array([[37.708324],
#        [37.740616],
#        [37.804214],
#        ...,
#        [50.99279 ],
#        [51.128464],
#        [51.494793]], dtype=float32)

# %%
lookback=timestep
trainPlot=np.empty_like(df)
trainPlot[:,:]=np.nan
trainPlot[lookback:len(train_predict)+lookback, :]=train_predict

testPlot=np.empty_like(df)
testPlot[:, :]=np.nan
testPlot[len(train_predict)+(lookback*2)+1:len(df)-1, :]=test_predict

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPlot)
plt.plot(testPlot,color='g')
plt.title('Graph comparison of predicted values')
plt.xlabel('Number of days')
plt.ylabel('Opening Stock Prices')
plt.legend(['Orginal values','Train predicted values','Test Predicted Values'],loc=2)

# %%
def errorpercentage(y_test,pred):
    mape=np.mean(np.abs(y_test-pred)/y_test)*100
    return mape

# %%
print('Accuracy using Stacked LSTM',100-errorpercentage(scaler.inverse_transform(y_test),test_predict))
# Out:
# Accuracy using Stacked LSTM 98.63939720988834

# %%
a=test_data.shape[0]
x=test_data[a-timestep:]
scaler.inverse_transform(x)
# Out:
# array([[48.84000015],
#        [49.22000122],
#        [48.95999908],
#        [49.25      ],
#        [48.93999863],
#        [49.34999847],
#        [49.91999817],
#        [49.63000107],
#        [49.70000076],
#        [49.58000183],
#        [48.40999985],
#        [48.36000061],
#        [49.13999939],
#        [49.84000015],
#        [49.52999878],
#        [49.52999878],
#        [49.65999985],
#        [49.65000153],
#        [50.74000168],
#        [50.77000046],
#        [50.81999969],
#        [51.        ],
#        [50.65000153],
#        [51.43999863],
#        [50.90999985],
#        [50.83000183],
#        [50.97000122],
#        [51.33000183],
#        [51.36000061],
#        [50.95999908]])

# %%
x.shape
# Out:
# (30, 1)

# %%
pred_stocks = data.DataReader(bank, 'yahoo', end+timedelta(1), end+timedelta(22))## reading data for next 15 days

# %%
pred_stocks
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-01-02  52.060001  51.169998  51.200001  52.040001   7808000  48.584858
# 2020-01-03  51.450001  50.830002  51.220001  51.200001   6706000  47.800640
# 2020-01-06  51.040001  50.459999  50.669998  51.020000   7476700  47.632587
# 2020-01-07  51.189999  50.709999  51.040001  50.919998   4538100  47.539227
# 2020-01-08  51.790001  50.900002  50.959999  51.570000   6185200  48.146065
# 2020-01-09  52.250000  51.820000  52.169998  52.060001   7308000  48.603535
# 2020-01-10  52.470001  51.919998  52.150002  52.209999   7686800  48.743572
# 2020-01-13  52.779999  52.070000  52.209999  52.779999   8334200  49.275726
# 2020-01-14  53.250000  52.680000  53.060001  52.860001   9602000  49.350422
# 2020-01-15  52.939999  52.110001  52.480000  52.939999  11342500  49.425106
# 2020-01-16  57.360001  55.650002  56.049999  56.439999  34590700  52.692730
# 2020-01-17  57.570000  56.180000  56.259998  57.509998  15403900  53.691689
# 2020-01-21  56.480000  55.180000  55.880001  55.919998  20833900  52.207249
# 2020-01-22  56.509998  55.849998  56.180000  55.860001  10276800  52.151234
# 2020-01-23  55.650002  54.799999  55.220001  55.529999  10064500  51.843143

# %%
actual_values=[]
for i in pred_stocks['Open']:
    actual_values.append(i)
actual_values=np.array(actual_values)

# %%
actual_values
# Out:
# array([51.20000076, 51.22000122, 50.66999817, 51.04000092, 50.95999908,
#        52.16999817, 52.15000153, 52.20999908, 53.06000137, 52.47999954,
#        56.04999924, 56.25999832, 55.88000107, 56.18000031, 55.22000122])

# %%
## Prediction for next 15 days
i=0
while(i<15):
    length_of_array=len(x)
    if(length_of_array==timestep):
        temp=x;
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    else:
        temp=x[length_of_array-timestep:]
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    i=i+1

# %%
x=x.reshape(-1,1)
actual_values=actual_values.reshape(-1,1)
scaler.inverse_transform(x[timestep:])
# Out:
# array([[51.1999576 ],
#        [51.371411  ],
#        [51.55682963],
#        [51.74659538],
#        [51.93383261],
#        [52.11341618],
#        [52.28367826],
#        [52.44577612],
#        [52.6028461 ],
#        [52.75819961],
#        [52.91491949],
#        [53.07574822],
#        [53.24192089],
#        [53.41348127],
#        [53.58990905]])

# %%
act,pred=actual_values[:i],scaler.inverse_transform(x[timestep:])

# %%
scaler.inverse_transform(x[timestep:])
# Out:
# array([[51.1999576 ],
#        [51.371411  ],
#        [51.55682963],
#        [51.74659538],
#        [51.93383261],
#        [52.11341618],
#        [52.28367826],
#        [52.44577612],
#        [52.6028461 ],
#        [52.75819961],
#        [52.91491949],
#        [53.07574822],
#        [53.24192089],
#        [53.41348127],
#        [53.58990905]])

# %%
print('Accuracy for Future 15 days values',100-errorpercentage(act,pred))
# Out:
# Accuracy for Future 15 days values 97.90667060401802

# %%
from sklearn.metrics import mean_absolute_error

# %%
print('MSE for future 15 days values',mean_absolute_error(act,pred))
# Out:
# MSE for future 15 days values 1.1489416469669058

# %%
y=len(df)-1460
Plotarr=np.empty([y+15,1])
Plotarr[::]=np.nan
Plotarr[y:]=pred

# %%
pred    ## stocks for the next 15 days
# Out:
# array([[51.1999576 ],
#        [51.371411  ],
#        [51.55682963],
#        [51.74659538],
#        [51.93383261],
#        [52.11341618],
#        [52.28367826],
#        [52.44577612],
#        [52.6028461 ],
#        [52.75819961],
#        [52.91491949],
#        [53.07574822],
#        [53.24192089],
#        [53.41348127],
#        [53.58990905]])

# %%
print('The above shows the predicted stock price for 15 days')
# Out:
# The above shows the predicted stock price for 15 days

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df[1460:])) ## for the 
plt.plot(Plotarr)
plt.legend(['Orignal Open Price values over the last 6 years','Future Predicted values (15 days)'],loc=2)

# %%
f=pd.DataFrame(pred,columns=['Open'])

# %%
string=bank+'Data'
dfnew=pd.read_csv(string)

# %%
dfnew['Open']=pred

# %%
dfnew.to_csv(string,index=False)

# %%
test=pd.read_csv(string)

# %%
dfnew
# Out:
#         Close       Open
# 0   51.472278  51.199958
# 1   51.799459  51.371411
# 2   52.059860  51.556830
# 3   52.293670  51.746595
# 4   52.529483  51.933833
# 5   52.772535  52.113416
# 6   53.019773  52.283678
# 7   53.268680  52.445776
# 8   53.518615  52.602846
# 9   53.769849  52.758200
# 10  54.022729  52.914919
# 11  54.277495  53.075748
# 12  54.534251  53.241921
# 13  54.793062  53.413481
# 14  55.053974  53.589909

# %%
modelBD.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=70,batch_size=40,verbose=1)
# Out:
# Epoch 1/70
# 66/66 [==============================] - 15s 70ms/step - loss: 0.5727 - accuracy: 7.6570e-04 - val_loss: 0.6505 - val_accuracy: 0.0000e+00
# Epoch 2/70
# 66/66 [==============================] - 2s 30ms/step - loss: 0.5294 - accuracy: 7.6570e-04 - val_loss: 0.6501 - val_accuracy: 0.0000e+00
# Epoch 3/70
# 66/66 [==============================] - 2s 30ms/step - loss: 0.5277 - accuracy: 7.6570e-04 - val_loss: 0.6498 - val_accuracy: 0.0000e+00
# Epoch 4/70
# 66/66 [==============================] - 2s 29ms/step - loss: 0.5270 - accuracy: 7.6570e-04 - val_loss: 0.6490 - val_accuracy: 0.0000e+00
# Epoch 5/70
# 66/66 [==============================] - 2s 30ms/step - loss: 0.5265 - accuracy: 7.6570e-04 - val_loss: 0.6488 - val_accuracy: 0.0000e+00
# Epoch 6/70
# 66/66 [==============================] - 2s 31ms/step - loss: 0.5266 - accuracy: 7.6570e-04 - val_loss: 0.6492 - val_accuracy: 0.0000e+00
# Epoch 7/70
# 66/66 [==============================] - 2s 30ms/step - loss: 0.5264 - accuracy: 7.6570e-04 - val_loss: 0.6494 - val_accuracy: 0.0000e+00
# Epoch 8/70
# 66/66 [==============================] - 2s 30ms/step - loss: 0.5261 - accuracy: 7.6570e-04 - val_loss: 0.6487 - val_accuracy: 0.0000e+00
# Epoch 9/70
# 66/66 [==============================] - 2s 31ms/step - loss: 0.5261 - accuracy: 7.6570e-04 - val_loss: 0.6486 - val_accuracy: 0.0000e+00
# Epoch 10/70
# 66/66 [==============================] - 2s 31ms/step - loss: 0.5258 - accuracy: 7.6570e-04 - val_loss: 0.6486 - val_accuracy: 0.0000e+00
# Epoch 11/70
# 66/66 [==============================] - 2s 31ms/step - loss: 0.5258 - accuracy: 7.6570e-04 - val_loss: 0.6496 - val_accuracy: 0.0000e+00
# Epoch 12/70
# 66/66 [==============================] - 2s 31ms/step - loss: 0.5256 - accuracy: 7.6570e-04 - val_loss: 0.6487 - val_accuracy: 0.0000e+00
# Epoch 13/70
# 66/66 [==============================] - 2s 33ms/step - loss: 0.5251 - accuracy: 7.6570e-04 - val_loss: 0.6490 - val_accuracy: 0.0000e+00
# Epoch 14/70
# 66/66 [==============================] - 2s 30ms/step - loss: 0.5248 - accuracy: 7.6570e-04 - val_loss: 0.6487 - val_accuracy: 0.0000e+00
# Epoch 15/70
# 66/66 [==============================] - 2s 32ms/step - loss: 0.5248 - accuracy: 7.6570e-04 - val_loss: 0.6485 - val_accuracy: 0.0000e+00
# Epoch 54/70
# 66/66 [==============================] - 2s 34ms/step - loss: 0.5237 - accuracy: 7.6570e-04 - val_loss: 0.6479 - val_accuracy: 0.0000e+00
# Epoch 55/70
# 66/66 [==============================] - 2s 27ms/step - loss: 0.5234 - accuracy: 7.6570e-04 - val_loss: 0.6480 - val_accuracy: 0.0000e+00
# Epoch 56/70
# 66/66 [==============================] - 2s 23ms/step - loss: 0.5239 - accuracy: 7.6570e-04 - val_loss: 0.6480 - val_accuracy: 0.0000e+00
# Epoch 57/70
# 66/66 [==============================] - 2s 27ms/step - loss: 0.5237 - accuracy: 7.6570e-04 - val_loss: 0.6480 - val_accuracy: 0.0000e+00
# Epoch 58/70
# 66/66 [==============================] - 2s 23ms/step - loss: 0.5237 - accuracy: 7.6570e-04 - val_loss: 0.6481 - val_accuracy: 0.0000e+00
# Epoch 59/70
# 66/66 [==============================] - 1s 18ms/step - loss: 0.5236 - accuracy: 7.6570e-04 - val_loss: 0.6480 - val_accuracy: 0.0000e+00
# Epoch 60/70
# 66/66 [==============================] - 1s 18ms/step - loss: 0.5235 - accuracy: 7.6570e-04 - val_loss: 0.6479 - val_accuracy: 0.0000e+00
# Epoch 61/70
# 66/66 [==============================] - 1s 18ms/step - loss: 0.5235 - accuracy: 7.6570e-04 - val_loss: 0.6481 - val_accuracy: 0.0000e+00
# Epoch 62/70
# 66/66 [==============================] - 1s 19ms/step - loss: 0.5234 - accuracy: 7.6570e-04 - val_loss: 0.6481 - val_accuracy: 0.0000e+00
# Epoch 63/70
# 66/66 [==============================] - 1s 18ms/step - loss: 0.5235 - accuracy: 7.6570e-04 - val_loss: 0.6479 - val_accuracy: 0.0000e+00
# Epoch 64/70
# 66/66 [==============================] - 1s 19ms/step - loss: 0.5236 - accuracy: 7.6570e-04 - val_loss: 0.6479 - val_accuracy: 0.0000e+00
# Epoch 65/70
# 66/66 [==============================] - 1s 18ms/step - loss: 0.5235 - accuracy: 7.6570e-04 - val_loss: 0.6479 - val_accuracy: 0.0000e+00
# Epoch 66/70
# 66/66 [==============================] - 1s 21ms/step - loss: 0.5233 - accuracy: 7.6570e-04 - val_loss: 0.6480 - val_accuracy: 0.0000e+00
# Epoch 67/70
# 66/66 [==============================] - 1s 19ms/step - loss: 0.5234 - accuracy: 7.6570e-04 - val_loss: 0.6480 - val_accuracy: 0.0000e+00
# Epoch 68/70
# 66/66 [==============================] - 1s 21ms/step - loss: 0.5235 - accuracy: 7.6570e-04 - val_loss: 0.6480 - val_accuracy: 0.0000e+00
# Epoch 69/70
# 66/66 [==============================] - 2s 24ms/step - loss: 0.5235 - accuracy: 7.6570e-04 - val_loss: 0.6480 - val_accuracy: 0.0000e+00
# Epoch 70/70
# 66/66 [==============================] - 1s 19ms/step - loss: 0.5233 - accuracy: 7.6570e-04 - val_loss: 0.6479 - val_accuracy: 0.0000e+00

# %%
train_predict=modelBD.predict(X_train)
test_predict=modelBD.predict(X_test)

# %%
trypredict=scaler.inverse_transform(test_predict)

# %%
trypredict
# Out:
# array([[38.463085],
#        [38.223404],
#        [38.068592],
#        ...,
#        [50.560757],
#        [50.52414 ],
#        [50.572178]], dtype=float32)

# %%
print('Accuracy using Bi-directional LSTM',100-errorpercentage(scaler.inverse_transform(y_test),trypredict))
# Out:
# Accuracy using Bi-directional LSTM 97.79718221787388
