# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_datareader import data, wb
import datetime
import tensorflow as tf
from datetime import date, timedelta
# %matplotlib inline

# %%
start = datetime.datetime(2005, 1, 1)
end = datetime.datetime(2020, 1, 1)

# %%
bank="JPM"
stocks = data.DataReader(bank, 'yahoo', start, end)

# %%
stocks.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2004-12-31  39.169998  38.950001  39.080002  39.009998   5754000.0  24.427870
# 2005-01-03  39.689999  39.009998  39.480000  39.150002  14957900.0  24.515524
# 2005-01-04  39.060001  38.320000  38.980000  38.410000  11360900.0  24.262865
# 2005-01-05  38.919998  38.389999  38.599998  38.490002   9770200.0  24.313408
# 2005-01-06  38.980000  38.639999  38.770000  38.709999   9115900.0  24.452366

# %%
plt.figure(figsize=(14,14))
plt.plot(stocks['Open'])
plt.title('Historical Stock Value')
plt.xlabel('Years')
plt.ylabel('Opening Stock Price')
# Out:
# Text(0, 0.5, 'Opening Stock Price')

# %%
df=stocks.reset_index()['Open']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
train_size=int(len(df)*0.70)
test_size=len(df)-train_size
train_data=df[0:train_size]
test_data=df[train_size:]

# %%
def make_dataset(data,timestep):
    X=[]
    y=[]
    n=len(data)
    for i in range(0,n-timestep-1):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X),np.array(y)

# %%
timestep=30
X_train,y_train=make_dataset(train_data,timestep)
X_test,y_test=make_dataset(test_data,timestep)
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(40,return_sequences=True,input_shape=(timestep,1)))
model.add(LSTM(40,return_sequences=True))
model.add(LSTM(40))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam') ##Stacked LSTM

# %%
import numpy as np
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional
from keras.datasets import imdb

# %%
modelBD = Sequential()
modelBD.add(Bidirectional(LSTM(64)))
modelBD.add(Dropout(0.5))
modelBD.add(Dense(1,activation='sigmoid'))
modelBD.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy']) ## Creating Bi-Directional LSTM

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 40)            6720
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 40)            12960
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 40)                12960
# _________________________________________________________________
# dense (Dense)                (None, 1)                 41
# =================================================================
# Total params: 32,681
# Trainable params: 32,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=70,batch_size=40,verbose=1)
# Out:
# Epoch 1/70
# 66/66 [==============================] - 6s 35ms/step - loss: 0.0048 - val_loss: 0.0023
# Epoch 2/70
# 66/66 [==============================] - 2s 24ms/step - loss: 3.3473e-04 - val_loss: 8.8480e-04 ETA: 0s - loss: 3.3
# Epoch 3/70
# 66/66 [==============================] - 2s 25ms/step - loss: 3.2678e-04 - val_loss: 8.7696e-04
# Epoch 4/70
# 66/66 [==============================] - 2s 25ms/step - loss: 3.1329e-04 - val_loss: 0.0018
# Epoch 5/70
# 66/66 [==============================] - 2s 25ms/step - loss: 3.1233e-04 - val_loss: 8.1372e-04
# Epoch 6/70
# 66/66 [==============================] - 2s 26ms/step - loss: 2.9418e-04 - val_loss: 8.3439e-04
# Epoch 7/70
# 66/66 [==============================] - 2s 25ms/step - loss: 2.9049e-04 - val_loss: 6.0628e-04
# Epoch 8/70
# 66/66 [==============================] - 2s 25ms/step - loss: 2.5538e-04 - val_loss: 6.9780e-04
# Epoch 9/70
# 66/66 [==============================] - 2s 26ms/step - loss: 2.5349e-04 - val_loss: 0.0013
# Epoch 61/70
# 66/66 [==============================] - 2s 28ms/step - loss: 6.9579e-05 - val_loss: 1.6239e-04
# Epoch 62/70
# 66/66 [==============================] - 2s 28ms/step - loss: 6.6699e-05 - val_loss: 1.2681e-04
# Epoch 63/70
# 66/66 [==============================] - 2s 28ms/step - loss: 7.2252e-05 - val_loss: 1.8763e-04
# Epoch 64/70
# 66/66 [==============================] - 2s 28ms/step - loss: 7.1687e-05 - val_loss: 1.7659e-04
# Epoch 65/70
# 66/66 [==============================] - 2s 28ms/step - loss: 6.6084e-05 - val_loss: 3.8227e-04
# Epoch 66/70
# 66/66 [==============================] - 2s 30ms/step - loss: 6.6279e-05 - val_loss: 5.3230e-04
# Epoch 67/70
# 66/66 [==============================] - 2s 29ms/step - loss: 7.5007e-05 - val_loss: 1.3952e-04
# Epoch 68/70
# 66/66 [==============================] - 2s 29ms/step - loss: 7.2667e-05 - val_loss: 1.3338e-04
# Epoch 69/70
# 66/66 [==============================] - 2s 28ms/step - loss: 7.1338e-05 - val_loss: 2.6905e-04
# Epoch 70/70
# 66/66 [==============================] - 2s 28ms/step - loss: 6.6774e-05 - val_loss: 1.5335e-04

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
train_predict
# Out:
# array([[37.895645],
#        [38.074734],
#        [38.19871 ],
#        ...,
#        [70.29436 ],
#        [69.9285  ],
#        [68.67346 ]], dtype=float32)

# %%
test_predict
# Out:
# array([[ 68.37572],
#        [ 68.55231],
#        [ 68.74273],
#        ...,
#        [136.04686],
#        [136.50258],
#        [137.47684]], dtype=float32)

# %%
lookback=timestep
trainPlot=np.empty_like(df)
trainPlot[:,:]=np.nan
trainPlot[lookback:len(train_predict)+lookback, :]=train_predict

testPlot=np.empty_like(df)
testPlot[:, :]=np.nan
testPlot[len(train_predict)+(lookback*2)+1:len(df)-1, :]=test_predict

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPlot)
plt.plot(testPlot,color='g')
plt.title('Graph comparison of predicted values')
plt.xlabel('Number of days')
plt.ylabel('Opening Stock Prices')
plt.legend(['Orginal values','Train predicted values','Test Predicted Values'],loc=2)

# %%
def errorpercentage(y_test,pred):
    mape=np.mean(np.abs(y_test-pred)/y_test*100)
    return mape

# %%
print('Accuracy using Stacked LSTM',100-errorpercentage(scaler.inverse_transform(y_test),test_predict))
# Out:
# Accuracy using Stacked LSTM 98.62134747079782

# %%
a=test_data.shape[0]
x=test_data[a-timestep:]
scaler.inverse_transform(x)
# Out:
# array([[129.55999756],
#        [130.99000549],
#        [130.30000305],
#        [130.        ],
#        [130.1499939 ],
#        [131.25      ],
#        [131.82000732],
#        [132.28999329],
#        [131.86999512],
#        [132.30999756],
#        [129.77000427],
#        [130.38000488],
#        [132.67999268],
#        [134.69000244],
#        [134.63000488],
#        [133.25      ],
#        [134.28999329],
#        [134.49000549],
#        [137.94999695],
#        [138.38000488],
#        [137.72999573],
#        [138.1499939 ],
#        [137.75999451],
#        [138.02000427],
#        [137.6000061 ],
#        [137.33000183],
#        [137.88999939],
#        [139.30000305],
#        [139.8999939 ],
#        [138.50999451]])

# %%
x.shape
# Out:
# (30, 1)

# %%
pred_stocks = data.DataReader(bank, 'yahoo', end+timedelta(1), end+timedelta(22))## reading data for next 15 days

# %%
pred_stocks
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  141.100006  139.259995  139.789993  141.089996  10803700.0
# 2020-01-03  139.229996  137.080002  137.500000  138.339996  10386800.0
# 2020-01-06  138.270004  136.500000  136.559998  138.229996  10259000.0
# 2020-01-07  137.860001  135.820007  137.279999  135.880005  10531300.0
# 2020-01-08  137.580002  135.600006  135.699997  136.940002   9695300.0
# 2020-01-09  138.229996  137.039993  138.050003  137.440002   9469000.0
# 2020-01-10  137.250000  135.809998  137.210007  136.070007  10190900.0
# 2020-01-13  137.199997  135.759995  136.190002  137.199997  12355200.0
# 2020-01-14  140.759995  137.690002  137.940002  138.800003  24906000.0
# 2020-01-15  138.600006  136.149994  137.850006  136.720001  16293400.0
# 2020-01-16  137.899994  136.839996  137.449997  137.250000  10783800.0
# 2020-01-17  138.289993  137.320007  137.539993  138.199997  14697700.0
# 2020-01-21  138.070007  136.690002  137.190002  136.839996   8474200.0
# 2020-01-22  137.399994  136.380005  137.240005  136.679993   7549100.0
# 2020-01-23  136.740005  134.720001  135.710007  136.539993   9345700.0
#
#              Adj Close
# Date
# 2020-01-02  131.047974
# 2020-01-03  129.318588
# 2020-01-06  129.215790
# 2020-01-07  127.019043
# 2020-01-08  128.009903
# 2020-01-09  128.477325
# 2020-01-10  127.196655
# 2020-01-13  128.252945
# 2020-01-14  129.748657
# 2020-01-15  127.804276
# 2020-01-16  128.299713
# 2020-01-17  129.187744
# 2020-01-21  127.916420
# 2020-01-22  127.766861
# 2020-01-23  127.635994

# %%
actual_values=[]
for i in pred_stocks['Open']:
    actual_values.append(i)
actual_values=np.array(actual_values)

# %%
actual_values
# Out:
# array([139.78999329, 137.5       , 136.55999756, 137.27999878,
#        135.69999695, 138.05000305, 137.21000671, 136.19000244,
#        137.94000244, 137.8500061 , 137.44999695, 137.53999329,
#        137.19000244, 137.24000549, 135.71000671])

# %%
## Prediction for next 15 days
i=0
while(i<15):
    length_of_array=len(x)
    if(length_of_array==timestep):
        temp=x;
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    else:
        temp=x[length_of_array-timestep:]
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    i=i+1

# %%
x=x.reshape(-1,1)
actual_values=actual_values.reshape(-1,1)
scaler.inverse_transform(x[timestep:])
# Out:
# array([[136.7614138 ],
#        [135.79238295],
#        [135.30273112],
#        [134.93624934],
#        [134.56419322],
#        [134.17361779],
#        [133.7924616 ],
#        [133.44456593],
#        [133.13759086],
#        [132.867454  ],
#        [132.6254635 ],
#        [132.40445659],
#        [132.1981909 ],
#        [132.00153744],
#        [131.81131934]])

# %%
act,pred=actual_values[:i],scaler.inverse_transform(x[timestep:])

# %%
scaler.inverse_transform(x[timestep:])
# Out:
# array([[136.7614138 ],
#        [135.79238295],
#        [135.30273112],
#        [134.93624934],
#        [134.56419322],
#        [134.17361779],
#        [133.7924616 ],
#        [133.44456593],
#        [133.13759086],
#        [132.867454  ],
#        [132.6254635 ],
#        [132.40445659],
#        [132.1981909 ],
#        [132.00153744],
#        [131.81131934]])

# %%
print('Accuracy for Future 15 days values',100-errorpercentage(act,pred))
# Out:
# Accuracy for Future 15 days values 97.40958288409023

# %%
from sklearn.metrics import mean_absolute_error

# %%
print('MSE for future 15 days values',mean_absolute_error(act,pred))
# Out:
# MSE for future 15 days values 3.5590922555679527

# %%
y=len(df)-1460
Plotarr=np.empty([y+15,1])
Plotarr[::]=np.nan
Plotarr[y:]=pred

# %%
pred    ## stocks for the next 15 days
# Out:
# array([[136.7614138 ],
#        [135.79238295],
#        [135.30273112],
#        [134.93624934],
#        [134.56419322],
#        [134.17361779],
#        [133.7924616 ],
#        [133.44456593],
#        [133.13759086],
#        [132.867454  ],
#        [132.6254635 ],
#        [132.40445659],
#        [132.1981909 ],
#        [132.00153744],
#        [131.81131934]])

# %%
print('The above shows the predicted stock price for 15 days')
# Out:
# The above shows the predicted stock price for 15 days

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df[1460:])) ## for the 
plt.plot(Plotarr)
plt.legend(['Orignal Open Price values over the last 6 years','Future Predicted values (15 days)'],loc=2)

# %%
f=pd.DataFrame(pred,columns=['Open'])

# %%
string=bank+'Data'
dfnew=pd.read_csv(string)

# %%
dfnew['Open']=pred

# %%
dfnew.to_csv(string,index=False)

# %%
test=pd.read_csv(string)

# %%
dfnew
# Out:
#          Close        Open
# 0   138.628687  136.761414
# 1   138.649472  135.792383
# 2   138.288061  135.302731
# 3   138.134215  134.936249
# 4   137.890441  134.564193
# 5   137.705685  134.173618
# 6   137.504288  133.792462
# 7   137.323688  133.444566
# 8   137.144425  133.137591
# 9   136.975743  132.867454
# 10  136.812422  132.625463
# 11  136.656610  132.404457
# 12  136.506742  132.198191
# 13  136.363126  132.001537
# 14  136.225188  131.811319

# %%
modelBD.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=70,batch_size=40,verbose=1)
# Out:
# Epoch 1/70
# 66/66 [==============================] - 4s 24ms/step - loss: 0.5713 - accuracy: 3.8285e-04 - val_loss: 1.1150 - val_accuracy: 0.0000e+00
# Epoch 2/70
# 66/66 [==============================] - 1s 16ms/step - loss: 0.5399 - accuracy: 3.8285e-04 - val_loss: 0.7713 - val_accuracy: 0.0000e+00
# Epoch 3/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5300 - accuracy: 3.8285e-04 - val_loss: 0.6798 - val_accuracy: 9.0744e-04
# Epoch 4/70
# 66/66 [==============================] - 1s 14ms/step - loss: 0.5293 - accuracy: 3.8285e-04 - val_loss: 0.6503 - val_accuracy: 9.0744e-04
# Epoch 5/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5291 - accuracy: 3.8285e-04 - val_loss: 0.6489 - val_accuracy: 9.0744e-04
# Epoch 6/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.
70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5272 - accuracy: 3.8285e-04 - val_loss: 0.6100 - val_accuracy: 9.0744e-04
# Epoch 54/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5273 - accuracy: 3.8285e-04 - val_loss: 0.6122 - val_accuracy: 9.0744e-04
# Epoch 55/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5272 - accuracy: 3.8285e-04 - val_loss: 0.6131 - val_accuracy: 9.0744e-04
# Epoch 56/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5272 - accuracy: 3.8285e-04 - val_loss: 0.6167 - val_accuracy: 9.0744e-04
# Epoch 57/70
# 66/66 [==============================] - 1s 17ms/step - loss: 0.5271 - accuracy: 3.8285e-04 - val_loss: 0.6147 - val_accuracy: 9.0744e-04
# Epoch 58/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5271 - accuracy: 3.8285e-04 - val_loss: 0.6162 - val_accuracy: 9.0744e-04
# Epoch 59/70
# 66/66 [==============================] - 1s 16ms/step - loss: 0.5271 - accuracy: 3.8285e-04 - val_loss: 0.6130 - val_accuracy: 9.0744e-04
# Epoch 60/70
# 66/66 [==============================] - 1s 16ms/step - loss: 0.5271 - accuracy: 3.8285e-04 - val_loss: 0.6203 - val_accuracy: 9.0744e-04
# Epoch 61/70
# 66/66 [==============================] - 1s 16ms/step - loss: 0.5271 - accuracy: 3.8285e-04 - val_loss: 0.6167 - val_accuracy: 9.0744e-04
# Epoch 62/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5271 - accuracy: 3.8285e-04 - val_loss: 0.6155 - val_accuracy: 9.0744e-04
# Epoch 63/70
# 66/66 [==============================] - 1s 17ms/step - loss: 0.5270 - accuracy: 3.8285e-04 - val_loss: 0.6196 - val_accuracy: 9.0744e-04
# Epoch 64/70
# 66/66 [==============================] - 1s 16ms/step - loss: 0.5271 - accuracy: 3.8285e-04 - val_loss: 0.6191 - val_accuracy: 9.0744e-04
# Epoch 65/70
# 66/66 [==============================] - 1s 16ms/step - loss: 0.5270 - accuracy: 3.8285e-04 - val_loss: 0.6187 - val_accuracy: 9.0744e-04
# Epoch 66/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5270 - accuracy: 3.8285e-04 - val_loss: 0.6216 - val_accuracy: 9.0744e-04
# Epoch 67/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5271 - accuracy: 3.8285e-04 - val_loss: 0.6158 - val_accuracy: 9.0744e-04
# Epoch 68/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5270 - accuracy: 3.8285e-04 - val_loss: 0.6164 - val_accuracy: 9.0744e-04
# Epoch 69/70
# 66/66 [==============================] - 1s 15ms/step - loss: 0.5269 - accuracy: 3.8285e-04 - val_loss: 0.6199 - val_accuracy: 9.0744e-04
# Epoch 70/70
# 66/66 [==============================] - 1s 16ms/step - loss: 0.5270 - accuracy: 3.8285e-04 - val_loss: 0.6169 - val_accuracy: 9.0744e-04

# %%
train_predict=modelBD.predict(X_train)
test_predict=modelBD.predict(X_test)

# %%
trypredict=scaler.inverse_transform(test_predict)

# %%
trypredict
# Out:
# array([[ 68.44171 ],
#        [ 68.29925 ],
#        [ 68.20094 ],
#        ...,
#        [104.546936],
#        [104.58428 ],
#        [104.642426]], dtype=float32)

# %%
print('Accuracy using Bi-directional LSTM',100-errorpercentage(scaler.inverse_transform(y_test),trypredict))
# Out:
# Accuracy using Bi-directional LSTM 92.55734802847505
