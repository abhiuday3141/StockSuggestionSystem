# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_datareader import data, wb
import datetime
from datetime import date, timedelta
# %matplotlib inline

# %%
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2020, 1, 1)

# %%
bank="MS"
stocks = data.DataReader(bank, 'yahoo', start, end)

# %%
stocks.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2009-12-31  29.770000  29.440001  29.490000  29.600000   9877503.0  22.393814
# 2010-01-04  31.968000  30.629999  30.700001  30.910000  20373994.0  23.384890
# 2010-01-05  32.130001  30.930000  31.010000  32.040001  22523317.0  24.239792
# 2010-01-06  32.590000  31.790001  31.969999  32.450001  17029777.0  24.549976
# 2010-01-07  33.270000  32.270000  32.459999  32.919998  18692919.0  24.905560

# %%
plt.figure(figsize=(14,14))
plt.plot(stocks['Close'])
plt.title('Historical Stock Value')
plt.xlabel('Years')
plt.ylabel('Closing Stock Price')
# Out:
# Text(0, 0.5, 'Closing Stock Price')

# %%
df=stocks.reset_index()['Close']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
train_size=int(len(df)*0.70)
test_size=len(df)-train_size
train_data=df[0:train_size]
test_data=df[train_size:]

# %%
def make_dataset(data,timestep):
    X=[]
    y=[]
    n=len(data)
    for i in range(0,n-timestep-1):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X),np.array(y)

# %%
timestep=90
X_train,y_train=make_dataset(train_data,timestep)
X_test,y_test=make_dataset(test_data,timestep)
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(timestep,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 90, 50)            10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 90, 50)            20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=40,verbose=1)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 7s 91ms/step - loss: 0.0144 - val_loss: 0.0023
# Epoch 2/100
# 42/42 [==============================] - 3s 76ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 3/100
# 42/42 [==============================] - 3s 76ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 4/100
# 42/42 [==============================] - 3s 75ms/step - loss: 9.6115e-04 - val_loss: 0.0015
# Epoch 5/100
# 42/42 [==============================] - 3s 79ms/step - loss: 9.3211e-04 - val_loss: 0.0018
# Epoch 6/100
# 42/42 [==============================] - 3s 77ms/step - loss: 8.6406e-04 - val_loss: 0.0014
# Epoch 7/100
# 42/42 [==============================] - 3s 78ms/step - loss: 7.7725e-04 - val_loss: 0.0015
# Epoch 8/100
# 42/42 [==============================] - 3s 79ms/step - loss: 7.0433e-04 - val_loss: 0.0016e-0
# Epoch 9/100
# 42/42 [==============================] - 3s 79ms/step - loss: 7.3125e-04 - val_loss: 0.0012
# Epoch 10/100
# 42/42 [==============================] - 3s 82ms/step - loss: 6.8723e-04 - val_loss: 0.0016
# Epoch 11/100
# 42/42 [==============================] - 3s 80ms/step - loss: 6.3153e-04 - val_loss: 0.0015
# Epoch 12/100
# 42/42 [==============================] - 3s 80ms/step - loss: 6.2033e-04 - val_loss: 0.0042
# Epoch 13/100
# 42/42 [==============================] - 3s 80ms/step - loss: 6.4208e-04 - val_loss: 0.0010
# Epoch 14/100
# 42/42 [==============================] - 3s 83ms/step - loss: 5.6957e-04 - val_loss: 0.0015
# Epoch 15/100
# 42/42 [==============================] - 3s 81ms/step - loss: 5.4546e-04 - val_loss: 9.0577e-04
# Epoch 16/100
# 42/42 [==============================] - 3s 81ms/step - loss: 5.4116e-04 - val_loss: 0.0019
# 42/42 [==============================] - 4s 96ms/step - loss: 1.7538e-04 - val_loss: 3.2481e-04
# Epoch 93/100
# 42/42 [==============================] - 4s 104ms/step - loss: 1.4502e-04 - val_loss: 3.7409e-04
# Epoch 94/100
# 42/42 [==============================] - 4s 100ms/step - loss: 1.4355e-04 - val_loss: 2.9051e-04
# Epoch 95/100
# 42/42 [==============================] - 4s 96ms/step - loss: 1.4570e-04 - val_loss: 2.9345e-04
# Epoch 96/100
# 42/42 [==============================] - 4s 94ms/step - loss: 1.5112e-04 - val_loss: 2.7041e-04
# Epoch 97/100
# 42/42 [==============================] - 4s 94ms/step - loss: 1.3768e-04 - val_loss: 2.7716e-04
# Epoch 98/100
# 42/42 [==============================] - 4s 98ms/step - loss: 1.5939e-04 - val_loss: 3.0037e-04
# Epoch 99/100
# 42/42 [==============================] - 4s 94ms/step - loss: 1.5129e-04 - val_loss: 2.9981e-04
# Epoch 100/100
# 42/42 [==============================] - 4s 94ms/step - loss: 1.3982e-04 - val_loss: 2.9401e-04

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
train_predict
# Out:
# array([[28.528915],
#        [27.923824],
#        [27.764616],
#        ...,
#        [43.47096 ],
#        [42.90989 ],
#        [43.49462 ]], dtype=float32)

# %%
test_predict
# Out:
# array([[43.030197],
#        [43.43555 ],
#        [42.99523 ],
#        [42.957386],
#        [43.85501 ],
#        [43.45897 ],
#        [40.569283],
#        [42.07114 ],
#        [42.170113],
#        [41.77135 ],
#        [42.82497 ],
#        [42.737938],
#        [42.7528  ],
#        [43.06729 ],
#        [42.297234],
#        [41.9099  ],
#        [43.139343],
#        [42.572235],
#        [43.173717],
#        [43.081116],
#        [43.530384],
#        [44.423378],
#        [45.12653 ],
#        [44.840034],
#        [45.40076 ],
#        [44.990845],
#        [44.90031 ],
#        [44.72079 ],
#        [46.325752],
#        [45.429947],
#        [45.012363],
#        [44.90467 ],
#        [43.783524],
#        [44.56134 ],
#        [44.50895 ],
#        [44.552048],
#        [45.073112],
#        [44.64405 ],
#        [46.12135 ],
#        [46.296417],
#        [46.186832],
#        [46.231735],
#        [46.212044],
#        [45.603527],
#        [45.197342],
#        [46.058304],
#        [45.266037],
#        [45.67637 ],
#        [45.309105],
#        [47.263195],
#        [46.37897 ],
#        [46.811245],
#        [46.931908],
#        [48.02669 ],
#        [47.11831 ],
#        [47.36351 ],
#        [46.82053 ],
#        [47.32737 ],
#        [47.510597],
#        [47.540188],
#        [47.45327 ],
#        [48.54731 ],
#        [48.406555],
#        [47.988335],
#        [47.902027],
#        [46.26077 ],
#        [46.106907],
#        [47.234356],
#        [46.515453],
#        [46.172726],
#        [45.186493],
#        [45.941105],
#        [44.697647],
#        [46.204865],
#        [45.907463],
#        [46.186718],
#        [46.067223],
#        [45.5577  ],
#        [45.62737 ],
#        [45.99567 ],
#        [45.609535],
#        [46.605026],
#        [44.616642],
#        [45.589783],
#        [44.014954],
#        [44.44009 ],
#        [45.718742],
#        [45.861885],
#        [46.36478 ],
#        [46.509525],
#        [46.749638],
#        [47.633297],
#        [47.775124],
#        [48.03879 ],
#        [48.488632],
#        [48.31778 ],
#        [47.83551 ],
#        [47.74704 ],
#        [48.572594],
#        [48.292576],
#        [48.404564],
#        [49.35796 ],
#        [49.424576],
#        [49.071438],
#        [50.096367],
#        [49.882656],
#        [49.491966],
#        [49.885796],
#        [49.350384],
#        [48.807713],
#        [48.69216 ],
#        [49.51457 ],
#        [49.310844],
#        [50.64201 ],
#        [49.660213],
#        [51.225834],
#        [50.58541 ],
#        [51.433994],
#        [50.49972 ],
#        [51.23592 ],
#        [51.478527],
#        [50.434097],
#        [50.356064],
#        [49.968113],
#        [51.06873 ],
#        [50.009785],
#        [50.569603],
#        [49.433445],
#        [49.443954],
#        [49.17513 ],
#        [49.12099 ],
#        [48.918808],
#        [48.633377],
#        [48.367367],
#        [49.081554],
#        [48.856995],
#        [49.422844],
#        [49.559288],
#        [49.141056],
#        [49.33715 ],
#        [49.219723],
#        [51.013126],
#        [51.400856],
#        [51.592674],
#        [52.098167],
#        [52.928425],
#        [51.805573],
#        [52.007393],
#        [52.880245],
#        [53.123608],
#        [52.846275],
#        [54.411846],
#        [52.925888],
#        [52.955822],
#        [53.69185 ],
#        [53.471043],
#        [53.13658 ],
#        [52.81379 ],
#        [53.44945 ],
#        [52.917282],
#        [52.794334],
#        [53.01355 ],
#        [52.981598],
#        [52.731834],
#        [52.494457],
#        [52.782707],
#        [53.630157],
#        [53.16841 ],
#        [53.109577],
#        [53.747868],
#        [54.251884],
#        [54.346893],
#        [55.511093],
#        [54.404057],
#        [55.929512],
#        [55.978077],
#        [57.931843],
#        [57.025066],
#        [56.99919 ],
#        [57.689598],
#        [56.871666],
#        [58.266556],
#        [57.48095 ],
#        [56.759094],
#        [57.187626],
#        [58.097214],
#        [55.05003 ],
#        [52.797768],
#        [56.32619 ],
#        [54.605534],
#        [51.4388  ],
#        [53.59986 ],
#        [54.146133],
#        [53.429977],
#        [55.82269 ],
#        [55.225574],
#        [55.160038],
#        [55.32041 ],
#        [55.372105],
#        [55.062984],
#        [56.74022 ],
#        [57.127655],
#        [56.5612  ],
#        [56.12982 ],
#        [54.555367],
#        [55.670902],
#        [56.025333],
#        [56.981274],
#        [56.9237  ],
#        [57.115723],
#        [59.27878 ],
#        [58.626434],
#        [57.919434],
#        [57.246586],
#        [57.965626],
#        [57.92202 ],
#        [57.120667],
#        [58.187393],
#        [57.22705 ],
#        [54.469757],
#        [52.626007],
#        [56.347954],
#        [52.693798],
#        [53.749184],
#        [54.75539 ],
#        [52.428955],
#        [54.051937],
#        [54.00723 ],
#        [55.325195],
#        [52.43567 ],
#        [54.24588 ],
#        [54.551144],
#        [52.40777 ],
#        [54.867817],
#        [52.68626 ],
#        [54.071297],
#        [53.359947],
#        [53.5925  ],
#        [55.343445],
#        [54.19796 ],
#        [53.710674],
#        [53.415222],
#        [52.239117],
#        [52.935528],
#        [52.09727 ],
#        [52.02034 ],
#        [52.277843],
#        [51.93313 ],
#        [51.245487],
#        [51.970814],
#        [52.85836 ],
#        [53.609016],
#        [54.239826],
#        [55.18447 ],
#        [55.098087],
#        [55.313057],
#        [54.926247],
#        [55.34985 ],
#        [55.08433 ],
#        [53.99608 ],
#        [55.11543 ],
#        [55.232883],
#        [54.38403 ],
#        [54.400078],
#        [53.187916],
#        [49.75885 ],
#        [52.69035 ],
#        [50.097023],
#        [52.22141 ],
#        [51.71589 ],
#        [50.760406],
#        [52.709835],
#        [52.136917],
#        [52.016315],
#        [52.038788],
#        [51.474   ],
#        [52.081497],
#        [51.42755 ],
#        [51.47467 ],
#        [50.979847],
#        [50.07458 ],
#        [50.42741 ],
#        [50.08115 ],
#        [48.962044],
#        [48.200962],
#        [48.320072],
#        [47.371887],
#        [49.03229 ],
#        [47.125053],
#        [48.237743],
#        [46.967087],
#        [46.994473],
#        [47.50547 ],
#        [48.866955],
#        [47.865475],
#        [47.8638  ],
#        [48.34141 ],
#        [48.21481 ],
#        [49.286877],
#        [49.22408 ],
#        [50.98853 ],
#        [49.448605],
#        [50.70528 ],
#        [50.94312 ],
#        [51.113556],
#        [51.19775 ],
#        [51.1732  ],
#        [51.318344],
#        [51.101616],
#        [50.784706],
#        [50.466785],
#        [50.130962],
#        [50.37298 ],
#        [50.313522],
#        [50.45653 ],
#        [50.370674],
#        [49.536488],
#        [48.577805],
#        [47.67091 ],
#        [48.63949 ],
#        [47.553593],
#        [48.93284 ],
#        [48.434612],
#        [48.462822],
#        [48.84018 ],
#        [48.762856],
#        [48.20102 ],
#        [48.485374],
#        [50.57069 ],
#        [49.784496],
#        [50.058292],
#        [49.305717],
#        [49.08484 ],
#        [49.067642],
#        [49.034973],
#        [47.984715],
#        [48.77858 ],
#        [48.06554 ],
#        [48.170746],
#        [47.656197],
#        [48.133667],
#        [48.50899 ],
#        [47.65215 ],
#        [48.242844],
#        [49.6119  ],
#        [49.972088],
#        [49.24804 ],
#        [48.618618],
#        [48.651585],
#        [47.891468],
#        [48.233788],
#        [46.50886 ],
#        [47.233723],
#        [46.91216 ],
#        [47.5001  ],
#        [47.43324 ],
#        [46.772774],
#        [47.424393],
#        [46.08621 ],
#        [44.631954],
#        [43.81357 ],
#        [43.96932 ],
#        [43.78291 ],
#        [46.76322 ],
#        [47.142628],
#        [45.51204 ],
#        [46.851467],
#        [44.84181 ],
#        [44.85503 ],
#        [43.609695],
#        [45.295876],
#        [43.84861 ],
#        [44.24436 ],
#        [44.839985],
#        [46.0014  ],
#        [45.85087 ],
#        [46.032326],
#        [45.91982 ],
#        [45.89767 ],
#        [47.059334],
#        [46.3895  ],
#        [45.773483],
#        [44.08024 ],
#        [45.44568 ],
#        [43.810093],
#        [44.844616],
#        [44.248466],
#        [44.72248 ],
#        [42.91448 ],
#        [44.35971 ],
#        [43.036636],
#        [44.901592],
#        [43.973454],
#        [45.811886],
#        [44.232094],
#        [44.670643],
#        [45.900845],
#        [42.50732 ],
#        [43.16014 ],
#        [41.38577 ],
#        [41.069946],
#        [40.992226],
#        [41.09932 ],
#        [40.70797 ],
#        [39.60791 ],
#        [39.903877],
#        [40.147263],
#        [39.285545],
#        [39.05432 ],
#        [37.640186],
#        [37.200024],
#        [40.007816],
#        [39.61743 ],
#        [39.31192 ],
#        [39.843513],
#        [40.6432  ],
#        [39.55925 ],
#        [41.850204],
#        [41.741947],
#        [41.431427],
#        [41.991665],
#        [41.774464],
#        [41.95291 ],
#        [42.834904],
#        [43.042885],
#        [44.95524 ],
#        [41.938686],
#        [44.485157],
#        [42.166073],
#        [42.553875],
#        [42.384907],
#        [43.488888],
#        [42.661655],
#        [42.724926],
#        [43.135586],
#        [42.36876 ],
#        [42.032852],
#        [42.960064],
#        [42.591824],
#        [42.585648],
#        [41.504963],
#        [41.043163],
#        [40.452152],
#        [41.724224],
#        [41.292458],
#        [40.78258 ],
#        [42.536366],
#        [42.189896],
#        [42.59501 ],
#        [41.986134],
#        [42.0116  ],
#        [42.53333 ],
#        [42.608578],
#        [42.752686],
#        [42.010357],
#        [42.922802],
#        [42.015133],
#        [42.164333],
#        [41.80311 ],
#        [41.332165],
#        [41.71122 ],
#        [42.159817],
#        [42.19026 ],
#        [42.64945 ],
#        [42.874702],
#        [43.609707],
#        [44.263863],
#        [43.976646],
#        [43.002167],
#        [43.55411 ],
#        [41.615402],
#        [41.65753 ],
#        [42.41625 ],
#        [41.393116],
#        [42.361458],
#        [42.38779 ],
#        [43.965008],
#        [43.682526],
#        [44.647236],
#        [45.10871 ],
#        [44.956715],
#        [45.19879 ],
#        [44.284866],
#        [44.88931 ],
#        [45.122414],
#        [47.31868 ],
#        [45.737328],
#        [47.550148],
#        [48.575127],
#        [47.269253],
#        [47.596207],
#        [47.69229 ],
#        [47.663822],
#        [47.556534],
#        [48.35939 ],
#        [48.744053],
#        [48.309155],
#        [47.692547],
#        [48.32819 ],
#        [48.376717],
#        [47.849888],
#        [46.813683],
#        [47.039165],
#        [46.80478 ],
#        [46.645767],
#        [43.897892],
#        [44.770004],
#        [44.25236 ],
#        [44.6932  ],
#        [43.94815 ],
#        [44.15419 ],
#        [44.7305  ],
#        [43.339035],
#        [42.87165 ],
#        [43.393753],
#        [42.138634],
#        [42.53398 ],
#        [41.93913 ],
#        [40.644867],
#        [41.118702],
#        [43.06293 ],
#        [42.265068],
#        [42.978336],
#        [42.722343],
#        [43.561104],
#        [43.801384],
#        [42.429337],
#        [43.381554],
#        [42.937965],
#        [42.64211 ],
#        [43.792217],
#        [43.129692],
#        [43.735546],
#        [43.736683],
#        [43.100037],
#        [42.856705],
#        [43.37544 ],
#        [43.780056],
#        [43.99747 ],
#        [44.110283],
#        [43.961964],
#        [44.255173],
#        [44.45191 ],
#        [43.483707],
#        [44.220234],
#        [43.38733 ],
#        [44.71634 ],
#        [45.108555],
#        [44.3702  ],
#        [44.71284 ],
#        [43.82971 ],
#        [44.967205],
#        [44.50503 ],
#        [44.75512 ],
#        [45.45499 ],
#        [45.688946],
#        [44.825817],
#        [46.300964],
#        [45.15121 ],
#        [44.85448 ],
#        [44.91311 ],
#        [42.78959 ],
#        [42.53101 ],
#        [40.545784],
#        [42.000687],
#        [40.564613],
#        [41.745186],
#        [41.640575],
#        [40.19421 ],
#        [41.11006 ],
#        [39.16749 ],
#        [39.42785 ],
#        [40.378036],
#        [40.513016],
#        [39.86019 ],
#        [40.139603],
#        [40.48902 ],
#        [39.225826],
#        [40.61202 ],
#        [39.780136],
#        [40.685196],
#        [41.563656],
#        [41.52468 ],
#        [40.970108],
#        [41.87797 ],
#        [42.77999 ],
#        [42.124783],
#        [43.52144 ],
#        [43.719173],
#        [44.10163 ],
#        [44.527084],
#        [45.477806],
#        [44.686142],
#        [44.36454 ],
#        [44.76756 ],
#        [44.185005],
#        [43.92819 ],
#        [43.890812],
#        [42.585518],
#        [43.64869 ],
#        [42.716003],
#        [43.224342],
#        [42.848488],
#        [41.323795],
#        [40.43659 ],
#        [40.74289 ],
#        [41.18074 ],
#        [40.797802],
#        [39.822155],
#        [40.8972  ],
#        [41.297832],
#        [42.18367 ],
#        [42.325016],
#        [42.664665],
#        [42.950848],
#        [43.704327],
#        [43.766434],
#        [45.40459 ],
#        [45.394077],
#        [46.095978],
#        [45.78439 ],
#        [46.73723 ],
#        [47.047306],
#        [46.936596],
#        [46.342003],
#        [46.383617],
#        [47.996216],
#        [49.18926 ],
#        [48.58985 ],
#        [48.722805],
#        [48.97112 ],
#        [49.531437],
#        [49.24145 ],
#        [49.29155 ],
#        [48.54333 ],
#        [49.15249 ],
#        [49.37279 ],
#        [49.25818 ],
#        [49.69715 ],
#        [49.2459  ],
#        [49.118633],
#        [49.73276 ],
#        [50.342846],
#        [49.350643],
#        [50.290245],
#        [49.57916 ],
#        [49.33553 ],
#        [48.2524  ],
#        [49.619007],
#        [49.26875 ],
#        [50.213116],
#        [49.600136],
#        [49.965378],
#        [49.616455],
#        [51.32549 ],
#        [50.0346  ],
#        [51.19175 ],
#        [51.05443 ],
#        [50.78007 ],
#        [51.23308 ],
#        [50.850082],
#        [51.048836],
#        [50.95429 ],
#        [51.51192 ],
#        [51.24274 ]], dtype=float32)

# %%
lookback=timestep
trainPlot=np.empty_like(df)
trainPlot[:,:]=np.nan
trainPlot[lookback:len(train_predict)+lookback, :]=train_predict

testPlot=np.empty_like(df)
testPlot[:, :]=np.nan
testPlot[len(train_predict)+(lookback*2)+1:len(df)-1, :]=test_predict

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPlot)
plt.plot(testPlot,color='g')
plt.title('Graph comparison of predicted values')
plt.xlabel('Number of days')
plt.ylabel('Stock Prices')
plt.legend(['Orginal values','Train predicted values','Test Predicted Values'],loc=2)

# %%
def errorpercentage(y_test,pred):
    mape=np.mean(np.abs(y_test-pred)/y_test*100)
    return mape

# %%
errorpercentage(scaler.inverse_transform(y_test),test_predict)
# Out:
# 1.2857746483947325

# %%
a=test_data.shape[0]
x=test_data[a-timestep:]
scaler.inverse_transform(x)
# Out:
# array([[39.33000183],
#        [40.15999985],
#        [39.79000092],
#        [40.38000107],
#        [41.29000092],
#        [41.49000168],
#        [40.99000168],
#        [41.52999878],
#        [42.47000122],
#        [42.18000031],
#        [43.11000061],
#        [43.58000183],
#        [43.93999863],
#        [44.31999969],
#        [45.15999985],
#        [44.75      ],
#        [44.20999908],
#        [44.36000061],
#        [44.02000046],
#        [43.66999817],
#        [43.56000137],
#        [42.54000092],
#        [43.04000092],
#        [42.61999893],
#        [42.84000015],
#        [42.66999817],
#        [41.38000107],
#        [40.22999954],
#        [40.25      ],
#        [40.77999878],
#        [40.68000031],
#        [39.81999969],
#        [40.43999863],
#        [41.04999924],
#        [41.93000031],
#        [42.25      ],
#        [42.52999878],
#        [42.79000092],
#        [43.43999863],
#        [43.65999985],
#        [44.97999954],
#        [45.38000107],
#        [45.90999985],
#        [45.75999832],
#        [46.36999893],
#        [46.84000015],
#        [46.83000183],
#        [46.25999832],
#        [46.04999924],
#        [47.33000183],
#        [48.83000183],
#        [48.75      ],
#        [48.56000137],
#        [48.65999985],
#        [49.15000153],
#        [49.09000015],
#        [49.00999832],
#        [48.38999939],
#        [48.61000061],
#        [48.99000168],
#        [49.02999878],
#        [49.33000183],
#        [49.09999847],
#        [48.84000015],
#        [49.25      ],
#        [49.95999908],
#        [49.40999985],
#        [49.77999878],
#        [49.47999954],
#        [49.08000183],
#        [48.11000061],
#        [48.84000015],
#        [49.06999969],
#        [49.79999924],
#        [49.59999847],
#        [49.66999817],
#        [49.45000076],
#        [50.68999863],
#        [50.24000168],
#        [50.72000122],
#        [50.90000153],
#        [50.65999985],
#        [50.86000061],
#        [50.68999863],
#        [50.72000122],
#        [50.68999863],
#        [51.11000061],
#        [51.09000015],
#        [50.95999908],
#        [51.11999893]])

# %%
x.shape
# Out:
# (90, 1)

# %%
pred_stocks = data.DataReader(bank, 'yahoo', end+timedelta(1), end+timedelta(22))

# %%
pred_stocks
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-01-02  52.060001  51.169998  51.200001  52.040001   7440294  46.067879
# 2020-01-03  51.450001  50.830002  51.220001  51.200001   6706712  45.324284
# 2020-01-06  51.040001  50.459999  50.669998  51.020000   7478540  45.164932
# 2020-01-07  51.189999  50.709999  51.040001  50.919998   4409027  45.076408
# 2020-01-08  51.790001  50.900002  50.959999  51.570000   6185249  45.651817
# 2020-01-09  52.250000  51.820000  52.169998  52.060001   7310275  46.085583
# 2020-01-10  52.470001  51.915001  52.150002  52.209999   7690485  46.218372
# 2020-01-13  52.779999  52.070000  52.209999  52.779999   8335362  46.722954
# 2020-01-14  53.244999  52.674999  53.060001  52.860001   9605014  46.793781
# 2020-01-15  52.939999  52.110001  52.480000  52.939999  11342486  46.864597
# 2020-01-16  57.360001  55.650002  56.049999  56.439999  34590664  49.962933
# 2020-01-17  57.570000  56.180000  56.259998  57.509998  15403886  50.910137
# 2020-01-21  56.480000  55.180000  55.880001  55.919998  20833888  49.502613
# 2020-01-22  56.509998  55.849998  56.180000  55.860001  10276830  49.449493
# 2020-01-23  55.650002  54.799999  55.220001  55.529999  10064905  49.157368

# %%
actual_values=[]
for i in pred_stocks['Close']:
    actual_values.append(i)
actual_values=np.array(actual_values)

# %%
actual_values
# Out:
# array([52.04000092, 51.20000076, 51.02000046, 50.91999817, 51.56999969,
#        52.06000137, 52.20999908, 52.77999878, 52.86000061, 52.93999863,
#        56.43999863, 57.50999832, 55.91999817, 55.86000061, 55.52999878])

# %%
## Prediction for next 15 days
i=0
while(i<15):
    length_of_array=len(x)
    if(length_of_array==timestep):
        temp=x;
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    else:
        temp=x[length_of_array-timestep:]
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    i=i+1

# %%
x=x.reshape(-1,1)
actual_values=actual_values.reshape(-1,1)
actual_values
scaler.inverse_transform(x[timestep:])
# Out:
# array([[51.47227848],
#        [51.79945886],
#        [52.05986027],
#        [52.29366994],
#        [52.52948287],
#        [52.77253473],
#        [53.01977345],
#        [53.2686797 ],
#        [53.51861533],
#        [53.76984947],
#        [54.02272894],
#        [54.27749514],
#        [54.53425073],
#        [54.79306229],
#        [55.05397422]])

# %%
act,pred=actual_values[:i],scaler.inverse_transform(x[timestep:])

# %%
scaler.inverse_transform(x[timestep:])
# Out:
# array([[51.47227848],
#        [51.79945886],
#        [52.05986027],
#        [52.29366994],
#        [52.52948287],
#        [52.77253473],
#        [53.01977345],
#        [53.2686797 ],
#        [53.51861533],
#        [53.76984947],
#        [54.02272894],
#        [54.27749514],
#        [54.53425073],
#        [54.79306229],
#        [55.05397422]])

# %%
errorpercentage(act,pred)
# Out:
# 2.0444139266762513

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(act,pred)
# Out:
# 1.1078755123331476

# %%
y=len(df)-1460
Plotarr=np.empty([y+15,1])
Plotarr[::]=np.nan
Plotarr[y:]=pred

# %%
pred    ## stocks for the next 15 days
# Out:
# array([[51.47227848],
#        [51.79945886],
#        [52.05986027],
#        [52.29366994],
#        [52.52948287],
#        [52.77253473],
#        [53.01977345],
#        [53.2686797 ],
#        [53.51861533],
#        [53.76984947],
#        [54.02272894],
#        [54.27749514],
#        [54.53425073],
#        [54.79306229],
#        [55.05397422]])

# %%
print('The above shows the predicted stock price for 15 days')
# Out:
# The above shows the predicted stock price for 15 days

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df[1460:])) ## for the 
plt.plot(Plotarr)
plt.legend(['Orignal closing Price over the last 6 years','Future Predicted values'],loc=2)

# %%
f=pd.DataFrame(pred, columns = ['Close'])

# %%
f.to_csv(bank+'Data',index=False)
