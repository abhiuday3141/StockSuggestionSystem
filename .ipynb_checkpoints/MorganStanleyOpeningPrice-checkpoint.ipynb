# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_datareader import data, wb
import datetime
from datetime import date, timedelta
# %matplotlib inline

# %%
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2020, 1, 1)

# %%
bank="MS"
stocks = data.DataReader(bank, 'yahoo', start, end)

# %%
stocks.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2009-12-31  29.770000  29.440001  29.490000  29.600000   9877503.0  22.393814
# 2010-01-04  31.968000  30.629999  30.700001  30.910000  20373994.0  23.384899
# 2010-01-05  32.130001  30.930000  31.010000  32.040001  22523317.0  24.239790
# 2010-01-06  32.590000  31.790001  31.969999  32.450001  17029777.0  24.549978
# 2010-01-07  33.270000  32.270000  32.459999  32.919998  18692919.0  24.905554

# %%
plt.figure(figsize=(14,14))
plt.plot(stocks['Open'])
plt.title('Historical Stock Value')
plt.xlabel('Years')
plt.ylabel('Opening Stock Price')
# Out:
# Text(0, 0.5, 'Opening Stock Price')

# %%
df=stocks.reset_index()['Open']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
train_size=int(len(df)*0.70)
test_size=len(df)-train_size
train_data=df[0:train_size]
test_data=df[train_size:]

# %%
def make_dataset(data,timestep):
    X=[]
    y=[]
    n=len(data)
    for i in range(0,n-timestep-1):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X),np.array(y)

# %%
timestep=5
X_train,y_train=make_dataset(train_data,timestep)
X_test,y_test=make_dataset(test_data,timestep)
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(timestep,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 50)             10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 50)             20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=40,verbose=1)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 4s 24ms/step - loss: 0.0259 - val_loss: 0.0170
# Epoch 2/100
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0089
# Epoch 3/100
# 44/44 [==============================] - 0s 7ms/step - loss: 4.6183e-04 - val_loss: 0.0020
# Epoch 4/100
# 44/44 [==============================] - 0s 7ms/step - loss: 4.3882e-04 - val_loss: 0.0022
# Epoch 5/100
# 44/44 [==============================] - 0s 8ms/step - loss: 4.2695e-04 - val_loss: 0.0015
# Epoch 6/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.9723e-04 - val_loss: 0.0013
# Epoch 7/100
# 44/44 [==============================] - 0s 7ms/step - loss: 4.1590e-04 - val_loss: 9.2973e-04
# Epoch 8/100
# 44/44 [==============================] - 0s 7ms/step - loss: 4.1873e-04 - val_loss: 7.8559e-04
# Epoch 9/100
# 44/44 [==============================] - 0s 7ms/step - loss: 4.1103e-04 - val_loss: 6.8200e-04
# Epoch 10/100
# 44/44 [==============================] - 0s 7ms/step - loss: 4.1737e-04 - val_loss: 6.7723e-04
# Epoch 11/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.9352e-04 - val_loss: 7.7938e-04
# Epoch 12/100
# 44/44 [==============================] - 0s 7ms/step - loss: 4.1180e-04 - val_loss: 7.4069e-04
# Epoch 13/100
# 44/44 [==============================] - 0s 7ms/step - loss: 4.0238e-04 - val_loss: 6.7223e-04
# Epoch 14/100
# 44/44 [==============================] - 0s 6ms/step - loss: 3.9139e-04 - val_loss: 7.1432e-04
# Epoch 15/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.9878e-04 - val_loss: 6.8040e-04
# Epoch 16/100
# 44/44 [==============================] - 0s 7ms/step - loss: 4.1173e-04 - val_loss: 6.9319e-04
# Epoch 17/100
# 44/44 [==============================] - 0s 7ms/step - loss: 4.2792e-04 - val_loss: 7.6855e-04
# Epoch 18/100
# 44/44 [==============================] - 0s 6ms/step - loss: 3.7446e-04 - val_loss: 8.0535e-04
# Epoch 19/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.8426e-04 - val_loss: 7.7165e-04
# Epoch 20/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.9886e-04 - val_loss: 0.0010
# Epoch 21/100
# 44/44 [==============================] - 0s 6ms/step - loss: 3.8334e-04 - val_loss: 6.6279e-04
# Epoch 22/100
# 44/44 [==============================] - 0s 6ms/step - loss: 3.8303e-04 - val_loss: 7.1962e-04
# Epoch 23/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.8293e-04 - val_loss: 6.8940e-04
# Epoch 24/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.9388e-04 - val_loss: 6.5955e-04
# Epoch 25/100
# 44/44 [==============================] - 0s 6ms/step - loss: 3.7002e-04 - val_loss: 6.8214e-04
# Epoch 26/100
# 44/44 [==============================] - 0s 8ms/step - loss: 3.9395e-04 - val_loss: 7.2535e-04
# Epoch 27/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.8963e-04 - val_loss: 7.3457e-04
# Epoch 28/100
# 44/44 [==============================] - 0s 6ms/step - loss: 3.7391e-04 - val_loss: 6.6104e-04
# Epoch 29/100
# 44/44 [==============================] - 0s 8ms/step - loss: 3.7912e-04 - val_loss: 6.8346e-04
# Epoch 30/100
# 44/44 [==============================] - 0s 9ms/step - loss: 3.6490e-04 - val_loss: 6.2673e-04
# Epoch 31/100
# 44/44 [==============================] - 0s 8ms/step - loss: 3.7541e-04 - val_loss: 6.3210e-04
# Epoch 32/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.8134e-04 - val_loss: 6.1973e-04
# Epoch 33/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.8831e-04 - val_loss: 6.3743e-04
# Epoch 34/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.5184e-04 - val_loss: 6.1192e-04
# Epoch 35/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.5524e-04 - val_loss: 6.0980e-04
# Epoch 36/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.5759e-04 - val_loss: 0.0010
# Epoch 37/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.7249e-04 - val_loss: 6.1580e-04
# Epoch 38/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.8206e-04 - val_loss: 6.1043e-04
# Epoch 39/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.9531e-04 - val_loss: 8.5389e-04
# Epoch 40/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.6299e-04 - val_loss: 6.8205e-04
# Epoch 41/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.4161e-04 - val_loss: 6.1274e-04
# Epoch 42/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.4681e-04 - val_loss: 6.1205e-04
# Epoch 43/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.5416e-04 - val_loss: 5.7969e-04
# Epoch 44/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.3541e-04 - val_loss: 5.6564e-04
# Epoch 45/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.4111e-04 - val_loss: 6.1924e-04
# Epoch 46/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.7748e-04 - val_loss: 6.0705e-04
# Epoch 47/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.4702e-04 - val_loss: 5.4991e-04
# Epoch 48/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.3159e-04 - val_loss: 5.5302e-04
# Epoch 49/100
# 44/44 [==============================] - 0s 8ms/step - loss: 3.3355e-04 - val_loss: 0.0016
# Epoch 50/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.4076e-04 - val_loss: 5.5857e-04
# Epoch 51/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.1164e-04 - val_loss: 7.8046e-04
# Epoch 52/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.3791e-04 - val_loss: 5.3144e-04
# Epoch 53/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.1412e-04 - val_loss: 5.8263e-04
# Epoch 54/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.0467e-04 - val_loss: 5.4054e-04
# Epoch 55/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.1615e-04 - val_loss: 5.1041e-04
# Epoch 56/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.1946e-04 - val_loss: 6.9704e-04
# Epoch 57/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.9652e-04 - val_loss: 6.1625e-04
# Epoch 58/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.0054e-04 - val_loss: 6.4601e-04
# Epoch 59/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.9179e-04 - val_loss: 4.8668e-04
# Epoch 60/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.9795e-04 - val_loss: 4.4059e-04
# Epoch 61/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.9960e-04 - val_loss: 7.5871e-04
# Epoch 62/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.9375e-04 - val_loss: 4.1984e-04
# Epoch 63/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.2554e-04 - val_loss: 0.0026
# Epoch 64/100
# 44/44 [==============================] - 0s 7ms/step - loss: 3.0767e-04 - val_loss: 4.3431e-04
# Epoch 65/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.6319e-04 - val_loss: 3.9709e-04
# Epoch 66/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.6850e-04 - val_loss: 3.8024e-04
# Epoch 67/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.7885e-04 - val_loss: 3.8017e-04
# Epoch 68/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.5035e-04 - val_loss: 5.1023e-04
# Epoch 69/100
# 44/44 [==============================] - 0s 8ms/step - loss: 2.5368e-04 - val_loss: 7.3112e-04
# Epoch 70/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.3677e-04 - val_loss: 3.4654e-04
# Epoch 71/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.2003e-04 - val_loss: 4.1949e-04
# Epoch 72/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.5253e-04 - val_loss: 0.0011
# Epoch 73/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.1574e-04 - val_loss: 6.5395e-04
# Epoch 74/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.1299e-04 - val_loss: 7.6798e-04
# Epoch 75/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.1183e-04 - val_loss: 5.6692e-04
# Epoch 76/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.9223e-04 - val_loss: 7.4669e-04
# Epoch 77/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.0789e-04 - val_loss: 5.3880e-04
# Epoch 78/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.9624e-04 - val_loss: 4.4880e-04
# Epoch 79/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.1064e-04 - val_loss: 5.3851e-04
# Epoch 80/100
# 44/44 [==============================] - 0s 8ms/step - loss: 1.9276e-04 - val_loss: 4.5343e-04
# Epoch 81/100
# 44/44 [==============================] - 0s 9ms/step - loss: 2.0124e-04 - val_loss: 6.4753e-04
# Epoch 82/100
# 44/44 [==============================] - 0s 8ms/step - loss: 1.8945e-04 - val_loss: 2.9380e-04
# Epoch 83/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.9440e-04 - val_loss: 3.0728e-04
# Epoch 84/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.0708e-04 - val_loss: 2.8588e-04
# Epoch 85/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.7548e-04 - val_loss: 3.2369e-04
# Epoch 86/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.7691e-04 - val_loss: 0.0012
# Epoch 87/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.6677e-04 - val_loss: 2.7921e-04
# Epoch 88/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.7455e-04 - val_loss: 8.8800e-04
# Epoch 89/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.8293e-04 - val_loss: 4.2371e-04
# Epoch 90/100
# 44/44 [==============================] - 0s 7ms/step - loss: 2.2655e-04 - val_loss: 8.1486e-04
# Epoch 91/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.7269e-04 - val_loss: 2.5234e-04
# Epoch 92/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.5950e-04 - val_loss: 6.8612e-04
# Epoch 93/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.5827e-04 - val_loss: 2.7925e-04
# Epoch 94/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.6262e-04 - val_loss: 5.9702e-04
# Epoch 95/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.8507e-04 - val_loss: 2.5768e-04
# Epoch 96/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.5845e-04 - val_loss: 2.4418e-04
# Epoch 97/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.5380e-04 - val_loss: 2.9715e-04
# Epoch 98/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.5187e-04 - val_loss: 3.0024e-04
# Epoch 99/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.4596e-04 - val_loss: 2.8696e-04
# Epoch 100/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.6904e-04 - val_loss: 2.7773e-04

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
train_predict
# Out:
# array([[32.54969 ],
#        [32.791645],
#        [32.644424],
#        ...,
#        [43.888756],
#        [43.683567],
#        [43.16696 ]], dtype=float32)

# %%
test_predict
# Out:
# array([[43.895275],
#        [43.924946],
#        [43.796803],
#        [43.264175],
#        [43.301414],
#        [43.80658 ],
#        [44.335934],
#        [44.1781  ],
#        [42.637836],
#        [42.583927],
#        [42.602623],
#        [42.415882],
#        [42.301777],
#        [43.3426  ],
#        [44.30998 ],
#        [44.254414],
#        [43.62951 ],
#        [43.283928],
#        [43.46261 ],
#        [42.486317],
#        [43.16684 ],
#        [44.501133],
#        [45.36268 ],
#        [45.129097],
#        [44.702736],
#        [45.35236 ],
#        [45.36053 ],
#        [45.52083 ],
#        [46.714043],
#        [46.914448],
#        [45.969387],
#        [46.475006],
#        [46.51482 ],
#        [46.90077 ],
#        [46.247818],
#        [45.71912 ],
#        [45.757866],
#        [47.190918],
#        [47.58652 ],
#        [46.712006],
#        [46.7594  ],
#        [46.895752],
#        [47.275894],
#        [46.954052],
#        [47.315956],
#        [47.002155],
#        [46.50436 ],
#        [46.451553],
#        [46.38674 ],
#        [46.509438],
#        [45.006596],
#        [44.802635],
#        [42.30912 ],
#        [41.776886],
#        [42.677826],
#        [41.00442 ],
#        [41.541267],
#        [43.17761 ],
#        [43.339806],
#        [43.66884 ],
#        [43.19386 ],
#        [42.777996],
#        [43.175316],
#        [41.972256],
#        [41.71032 ],
#        [41.99695 ],
#        [41.802   ],
#        [41.733112],
#        [41.089066],
#        [40.908073],
#        [41.127148],
#        [42.445816],
#        [43.048637],
#        [42.687935],
#        [43.62402 ],
#        [44.365185],
#        [44.635307],
#        [44.58098 ],
#        [43.929058],
#        [43.94279 ],
#        [43.89925 ],
#        [43.407967],
#        [44.00886 ],
#        [43.68405 ],
#        [43.399666],
#        [43.26123 ],
#        [43.00775 ],
#        [43.172436],
#        [42.878513],
#        [43.02095 ],
#        [43.767227],
#        [42.821728],
#        [41.25369 ],
#        [41.50395 ],
#        [42.140022],
#        [41.8569  ],
#        [42.556824],
#        [43.140545],
#        [42.86354 ],
#        [42.866684],
#        [42.4637  ],
#        [42.183598],
#        [42.32336 ],
#        [42.762333],
#        [42.776688],
#        [43.4002  ],
#        [43.6248  ],
#        [44.676743],
#        [45.51203 ],
#        [45.581463],
#        [44.982365],
#        [44.708855],
#        [44.968884],
#        [45.164944],
#        [45.798145],
#        [45.85037 ],
#        [45.045387],
#        [44.877605],
#        [44.153736],
#        [44.451244],
#        [44.704857],
#        [45.72965 ],
#        [45.795567],
#        [45.375725],
#        [46.147552],
#        [46.485565],
#        [46.724304],
#        [46.327488],
#        [46.0819  ],
#        [45.552624],
#        [45.333767],
#        [45.06773 ],
#        [45.336308],
#        [45.2094  ],
#        [47.218845],
#        [46.94606 ],
#        [46.516464],
#        [46.77682 ],
#        [47.5443  ],
#        [48.179737],
#        [47.58895 ],
#        [47.249207],
#        [47.154213],
#        [47.49577 ],
#        [47.463802],
#        [47.544044],
#        [48.117607],
#        [48.60887 ],
#        [48.669037],
#        [47.53674 ],
#        [47.42643 ],
#        [46.532276],
#        [46.29572 ],
#        [47.18675 ],
#        [46.958633],
#        [46.1105  ],
#        [45.070335],
#        [45.42681 ],
#        [45.214478],
#        [45.421234],
#        [46.258133],
#        [46.582882],
#        [46.570583],
#        [45.043034],
#        [45.49066 ],
#        [46.237606],
#        [45.973034],
#        [45.968822],
#        [45.305866],
#        [45.293995],
#        [44.41654 ],
#        [44.80727 ],
#        [45.610733],
#        [46.12693 ],
#        [46.842957],
#        [46.72296 ],
#        [47.18333 ],
#        [47.728584],
#        [48.15287 ],
#        [48.240486],
#        [48.411102],
#        [48.460384],
#        [48.011044],
#        [48.536118],
#        [48.723824],
#        [48.43841 ],
#        [48.389515],
#        [49.254498],
#        [49.676445],
#        [49.53774 ],
#        [50.36225 ],
#        [50.3621  ],
#        [49.709995],
#        [49.66224 ],
#        [49.530624],
#        [48.318756],
#        [48.320328],
#        [49.959854],
#        [49.91129 ],
#        [50.2265  ],
#        [50.898212],
#        [51.36185 ],
#        [51.262783],
#        [51.937626],
#        [51.10176 ],
#        [50.86712 ],
#        [50.785336],
#        [50.696617],
#        [50.458683],
#        [49.70145 ],
#        [50.341125],
#        [50.176086],
#        [50.575974],
#        [49.47963 ],
#        [48.880653],
#        [49.143116],
#        [48.437885],
#        [48.540085],
#        [48.046837],
#        [48.59658 ],
#        [48.617565],
#        [49.257206],
#        [50.07152 ],
#        [49.80185 ],
#        [49.645638],
#        [49.242428],
#        [49.38111 ],
#        [51.337173],
#        [52.52603 ],
#        [52.54494 ],
#        [53.733044],
#        [53.40223 ],
#        [51.882515],
#        [51.39662 ],
#        [53.293537],
#        [53.25715 ],
#        [53.25043 ],
#        [54.464977],
#        [53.815983],
#        [53.305775],
#        [54.20428 ],
#        [53.875954],
#        [53.656506],
#        [52.987705],
#        [53.21828 ],
#        [52.739548],
#        [52.50389 ],
#        [53.02908 ],
#        [53.090816],
#        [53.08903 ],
#        [52.548656],
#        [53.07429 ],
#        [53.592075],
#        [53.29237 ],
#        [53.381886],
#        [54.37089 ],
#        [54.62733 ],
#        [55.059414],
#        [56.25227 ],
#        [55.167213],
#        [56.34563 ],
#        [56.099934],
#        [56.938557],
#        [57.718277],
#        [57.69436 ],
#        [57.773945],
#        [57.36951 ],
#        [57.819874],
#        [56.829376],
#        [56.875706],
#        [56.68271 ],
#        [57.35474 ],
#        [54.53236 ],
#        [50.51739 ],
#        [53.761654],
#        [54.999588],
#        [52.81347 ],
#        [52.933525],
#        [53.22114 ],
#        [53.585854],
#        [56.181816],
#        [56.00293 ],
#        [55.351723],
#        [55.426395],
#        [55.74029 ],
#        [55.3202  ],
#        [56.792877],
#        [57.626038],
#        [57.624664],
#        [56.05984 ],
#        [53.907604],
#        [54.202564],
#        [56.271313],
#        [56.349514],
#        [57.592983],
#        [57.957447],
#        [59.330853],
#        [59.937202],
#        [58.74418 ],
#        [57.38246 ],
#        [57.42791 ],
#        [57.558792],
#        [57.389038],
#        [57.60044 ],
#        [56.38263 ],
#        [54.735374],
#        [52.983696],
#        [54.551132],
#        [53.38061 ],
#        [53.35412 ],
#        [54.121815],
#        [53.235397],
#        [52.251957],
#        [54.573624],
#        [54.647167],
#        [53.959415],
#        [54.465626],
#        [53.103024],
#        [53.494347],
#        [55.217808],
#        [53.78206 ],
#        [54.305622],
#        [54.214016],
#        [53.554768],
#        [55.328022],
#        [55.008743],
#        [54.22372 ],
#        [52.88456 ],
#        [51.902527],
#        [51.81731 ],
#        [52.353024],
#        [51.597492],
#        [52.025726],
#        [51.61913 ],
#        [50.873447],
#        [51.886444],
#        [53.044262],
#        [54.29053 ],
#        [54.938606],
#        [55.78425 ],
#        [55.94425 ],
#        [55.429493],
#        [54.74127 ],
#        [55.12396 ],
#        [54.795254],
#        [54.651245],
#        [54.71001 ],
#        [54.75212 ],
#        [54.363346],
#        [53.812893],
#        [52.12801 ],
#        [50.46343 ],
#        [50.547592],
#        [51.0312  ],
#        [51.91341 ],
#        [51.673077],
#        [51.199425],
#        [52.634113],
#        [52.583023],
#        [52.60468 ],
#        [52.190033],
#        [51.669556],
#        [51.92714 ],
#        [51.098633],
#        [50.843742],
#        [50.2964  ],
#        [50.266376],
#        [49.836807],
#        [50.188644],
#        [48.839794],
#        [47.96062 ],
#        [47.971912],
#        [47.365997],
#        [49.204876],
#        [47.371403],
#        [48.010155],
#        [47.562717],
#        [46.698566],
#        [47.44699 ],
#        [48.785477],
#        [48.14091 ],
#        [48.33021 ],
#        [48.399174],
#        [48.53596 ],
#        [49.384544],
#        [51.325268],
#        [51.17957 ],
#        [50.049877],
#        [50.51237 ],
#        [51.35097 ],
#        [51.434475],
#        [51.64164 ],
#        [51.44392 ],
#        [51.15361 ],
#        [51.22001 ],
#        [51.218456],
#        [49.987442],
#        [50.074383],
#        [50.081997],
#        [50.421154],
#        [50.466885],
#        [50.412083],
#        [49.074383],
#        [48.37006 ],
#        [47.507504],
#        [47.275642],
#        [47.98451 ],
#        [48.510048],
#        [48.74012 ],
#        [48.490112],
#        [48.65925 ],
#        [48.73969 ],
#        [48.653683],
#        [48.781807],
#        [50.464233],
#        [50.582283],
#        [50.21447 ],
#        [49.35018 ],
#        [48.985718],
#        [48.80126 ],
#        [48.742287],
#        [48.227375],
#        [48.56644 ],
#        [47.961758],
#        [47.982952],
#        [47.971836],
#        [48.155403],
#        [48.845398],
#        [48.237717],
#        [48.133533],
#        [50.109573],
#        [50.543114],
#        [49.860046],
#        [48.944904],
#        [48.45507 ],
#        [47.92956 ],
#        [47.527405],
#        [47.040253],
#        [46.82219 ],
#        [47.35884 ],
#        [47.706985],
#        [47.74573 ],
#        [46.81087 ],
#        [46.851444],
#        [46.54878 ],
#        [44.352   ],
#        [44.188976],
#        [43.46125 ],
#        [45.749767],
#        [46.515926],
#        [47.458878],
#        [46.629814],
#        [46.695774],
#        [44.28362 ],
#        [44.67009 ],
#        [44.108654],
#        [43.885414],
#        [44.75451 ],
#        [44.34903 ],
#        [45.38314 ],
#        [46.246586],
#        [46.997158],
#        [46.538002],
#        [46.08607 ],
#        [46.41396 ],
#        [46.633617],
#        [46.701546],
#        [45.82764 ],
#        [43.754795],
#        [44.94847 ],
#        [43.624916],
#        [44.047295],
#        [44.407013],
#        [44.182953],
#        [43.579918],
#        [43.428402],
#        [43.886837],
#        [44.314938],
#        [44.64682 ],
#        [45.256645],
#        [44.800686],
#        [45.33353 ],
#        [45.40514 ],
#        [42.04043 ],
#        [42.16733 ],
#        [41.14508 ],
#        [41.471497],
#        [41.331036],
#        [41.065205],
#        [40.31855 ],
#        [39.440727],
#        [39.90705 ],
#        [40.089775],
#        [39.248585],
#        [38.584225],
#        [37.749527],
#        [37.332394],
#        [38.364254],
#        [40.025517],
#        [40.208862],
#        [39.498825],
#        [40.27201 ],
#        [40.76845 ],
#        [41.79186 ],
#        [42.710648],
#        [42.422337],
#        [41.74554 ],
#        [41.451805],
#        [41.45927 ],
#        [42.361023],
#        [44.28496 ],
#        [43.147545],
#        [43.266983],
#        [42.701126],
#        [42.67237 ],
#        [42.208565],
#        [42.78339 ],
#        [42.752518],
#        [42.80009 ],
#        [42.63592 ],
#        [42.529232],
#        [42.530056],
#        [42.160442],
#        [42.54346 ],
#        [42.58176 ],
#        [42.396328],
#        [41.33381 ],
#        [41.068222],
#        [40.782894],
#        [41.56923 ],
#        [41.18035 ],
#        [41.35545 ],
#        [41.802197],
#        [42.36474 ],
#        [42.757294],
#        [42.44253 ],
#        [42.38591 ],
#        [42.227577],
#        [42.664288],
#        [42.800587],
#        [42.662457],
#        [42.799007],
#        [42.27875 ],
#        [42.022896],
#        [41.52463 ],
#        [40.76066 ],
#        [41.689617],
#        [42.226635],
#        [42.745583],
#        [42.704796],
#        [42.961254],
#        [43.756874],
#        [45.00276 ],
#        [44.316025],
#        [42.924194],
#        [42.601467],
#        [41.830425],
#        [41.778027],
#        [41.96445 ],
#        [41.733517],
#        [42.63049 ],
#        [43.127415],
#        [43.796455],
#        [44.662506],
#        [44.81012 ],
#        [45.523724],
#        [45.103752],
#        [44.94061 ],
#        [44.579315],
#        [44.931545],
#        [46.188725],
#        [46.973564],
#        [46.906673],
#        [48.27493 ],
#        [48.343716],
#        [47.7913  ],
#        [47.353603],
#        [47.320103],
#        [47.455936],
#        [47.699375],
#        [48.199436],
#        [48.923176],
#        [48.6465  ],
#        [47.97224 ],
#        [48.24019 ],
#        [47.198807],
#        [47.266727],
#        [46.700687],
#        [46.041702],
#        [46.374718],
#        [45.42527 ],
#        [44.29298 ],
#        [43.29663 ],
#        [44.003666],
#        [43.771584],
#        [43.717964],
#        [44.455994],
#        [44.46884 ],
#        [43.118343],
#        [43.094315],
#        [42.99968 ],
#        [41.989082],
#        [42.503906],
#        [41.411148],
#        [40.81884 ],
#        [41.444904],
#        [42.663742],
#        [42.72976 ],
#        [43.018414],
#        [43.554073],
#        [44.131165],
#        [43.8802  ],
#        [43.00744 ],
#        [43.302647],
#        [42.98368 ],
#        [42.78744 ],
#        [43.859337],
#        [43.997673],
#        [43.949738],
#        [43.806377],
#        [43.23171 ],
#        [42.95741 ],
#        [43.44645 ],
#        [44.46499 ],
#        [45.0373  ],
#        [44.176537],
#        [44.159416],
#        [44.704437],
#        [43.948612],
#        [43.293568],
#        [43.847664],
#        [43.766968],
#        [44.798355],
#        [45.440678],
#        [45.256287],
#        [44.60778 ],
#        [43.862167],
#        [44.44094 ],
#        [44.506607],
#        [45.059975],
#        [45.265945],
#        [45.846745],
#        [45.405426],
#        [45.90811 ],
#        [44.963387],
#        [44.856697],
#        [44.62379 ],
#        [42.949852],
#        [40.981907],
#        [40.73022 ],
#        [40.281513],
#        [41.007565],
#        [41.25462 ],
#        [41.072964],
#        [40.662903],
#        [39.80122 ],
#        [39.510784],
#        [39.61546 ],
#        [40.800583],
#        [40.49772 ],
#        [40.71616 ],
#        [40.64229 ],
#        [40.309002],
#        [40.05697 ],
#        [40.37086 ],
#        [39.7263  ],
#        [40.89626 ],
#        [41.971287],
#        [41.563774],
#        [41.72393 ],
#        [42.509056],
#        [42.847305],
#        [42.93028 ],
#        [43.571014],
#        [44.10987 ],
#        [43.93863 ],
#        [45.230747],
#        [44.991077],
#        [44.85097 ],
#        [44.207973],
#        [44.35981 ],
#        [44.46999 ],
#        [43.567467],
#        [43.889053],
#        [42.630848],
#        [42.98988 ],
#        [43.1739  ],
#        [43.325855],
#        [42.839146],
#        [41.30352 ],
#        [40.098362],
#        [40.224174],
#        [40.66814 ],
#        [40.350914],
#        [40.37794 ],
#        [41.000862],
#        [42.22517 ],
#        [42.270954],
#        [42.72614 ],
#        [42.949684],
#        [44.63865 ],
#        [44.145313],
#        [44.411613],
#        [45.178246],
#        [45.544876],
#        [46.4321  ],
#        [46.187485],
#        [46.8411  ],
#        [46.951603],
#        [46.619392],
#        [46.22195 ],
#        [46.732235],
#        [48.36606 ],
#        [49.6062  ],
#        [49.38005 ],
#        [49.5694  ],
#        [48.984993],
#        [49.11264 ],
#        [49.37865 ],
#        [48.81533 ],
#        [48.533993],
#        [49.108284],
#        [49.180634],
#        [49.583897],
#        [49.322468],
#        [49.556747],
#        [49.249725],
#        [49.636753],
#        [50.30813 ],
#        [50.033745],
#        [50.02685 ],
#        [49.868755],
#        [48.58735 ],
#        [48.429577],
#        [49.33957 ],
#        [50.265217],
#        [50.008343],
#        [49.87834 ],
#        [49.959637],
#        [49.952152],
#        [51.13901 ],
#        [51.268887],
#        [51.242165],
#        [51.37073 ],
#        [50.947533],
#        [51.773575],
#        [51.26192 ],
#        [51.088894],
#        [51.240185],
#        [51.65717 ]], dtype=float32)

# %%
lookback=timestep
trainPlot=np.empty_like(df)
trainPlot[:,:]=np.nan
trainPlot[lookback:len(train_predict)+lookback, :]=train_predict

testPlot=np.empty_like(df)
testPlot[:, :]=np.nan
testPlot[len(train_predict)+(lookback*2)+1:len(df)-1, :]=test_predict

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPlot)
plt.plot(testPlot,color='g')
plt.title('Graph comparison of predicted values')
plt.xlabel('Number of days')
plt.ylabel('Opening Stock Prices')
plt.legend(['Orginal values','Train predicted values','Test Predicted Values'],loc=2)

# %%
def errorpercentage(y_test,pred):
    mape=np.mean(np.abs(y_test-pred)/y_test*100)
    return mape

# %%
errorpercentage(scaler.inverse_transform(y_test),test_predict)
# Out:
# 1.301382800309778

# %%
a=test_data.shape[0]
x=test_data[a-timestep:]
scaler.inverse_transform(x)
# Out:
# array([[50.83000183],
#        [50.97000122],
#        [51.33000183],
#        [51.36000061],
#        [50.95999908]])

# %%
x.shape
# Out:
# (5, 1)

# %%
pred_stocks = data.DataReader(bank, 'yahoo', end+timedelta(1), end+timedelta(22))

# %%
pred_stocks
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-01-02  52.060001  51.169998  51.200001  52.040001   7440294  46.067879
# 2020-01-03  51.450001  50.830002  51.220001  51.200001   6706712  45.324276
# 2020-01-06  51.040001  50.459999  50.669998  51.020000   7478540  45.164932
# 2020-01-07  51.189999  50.709999  51.040001  50.919998   4409027  45.076405
# 2020-01-08  51.790001  50.900002  50.959999  51.570000   6185249  45.651814
# 2020-01-09  52.250000  51.820000  52.169998  52.060001   7310275  46.085587
# 2020-01-10  52.470001  51.915001  52.150002  52.209999   7690485  46.218372
# 2020-01-13  52.779999  52.070000  52.209999  52.779999   8335362  46.722958
# 2020-01-14  53.244999  52.674999  53.060001  52.860001   9605014  46.793781
# 2020-01-15  52.939999  52.110001  52.480000  52.939999  11342486  46.864597
# 2020-01-16  57.360001  55.650002  56.049999  56.439999  34590664  49.962936
# 2020-01-17  57.570000  56.180000  56.259998  57.509998  15403886  50.910145
# 2020-01-21  56.480000  55.180000  55.880001  55.919998  20833888  49.502605
# 2020-01-22  56.509998  55.849998  56.180000  55.860001  10276830  49.449493
# 2020-01-23  55.650002  54.799999  55.220001  55.529999  10064905  49.157364

# %%
actual_values=[]
for i in pred_stocks['Open']:
    actual_values.append(i)
actual_values=np.array(actual_values)

# %%
actual_values
# Out:
# array([51.20000076, 51.22000122, 50.66999817, 51.04000092, 50.95999908,
#        52.16999817, 52.15000153, 52.20999908, 53.06000137, 52.47999954,
#        56.04999924, 56.25999832, 55.88000107, 56.18000031, 55.22000122])

# %%
## Prediction for next 15 days
i=0
while(i<15):
    length_of_array=len(x)
    if(length_of_array==timestep):
        temp=x;
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    else:
        temp=x[length_of_array-timestep:]
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    i=i+1

# %%
x=x.reshape(-1,1)
actual_values=actual_values.reshape(-1,1)
scaler.inverse_transform(x[timestep:])
# Out:
# array([[51.26048286],
#        [51.5317888 ],
#        [51.86928322],
#        [52.26687103],
#        [52.71117184],
#        [53.18036066],
#        [53.67300188],
#        [54.18340373],
#        [54.70779804],
#        [55.24353073],
#        [55.78876284],
#        [56.34193463],
#        [56.90180227],
#        [57.46736449],
#        [58.03769897]])

# %%
act,pred=actual_values[:i],scaler.inverse_transform(x[timestep:])

# %%
scaler.inverse_transform(x[timestep:])
# Out:
# array([[51.26048286],
#        [51.5317888 ],
#        [51.86928322],
#        [52.26687103],
#        [52.71117184],
#        [53.18036066],
#        [53.67300188],
#        [54.18340373],
#        [54.70779804],
#        [55.24353073],
#        [55.78876284],
#        [56.34193463],
#        [56.90180227],
#        [57.46736449],
#        [58.03769897]])

# %%
errorpercentage(act,pred)
# Out:
# 2.3851013335004683

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(act,pred)
# Out:
# 1.2625152528850474

# %%
y=len(df)-1460
Plotarr=np.empty([y+15,1])
Plotarr[::]=np.nan
Plotarr[y:]=pred

# %%
pred    ## stocks for the next 15 days
# Out:
# array([[51.26048286],
#        [51.5317888 ],
#        [51.86928322],
#        [52.26687103],
#        [52.71117184],
#        [53.18036066],
#        [53.67300188],
#        [54.18340373],
#        [54.70779804],
#        [55.24353073],
#        [55.78876284],
#        [56.34193463],
#        [56.90180227],
#        [57.46736449],
#        [58.03769897]])

# %%
print('The above shows the predicted stock price for 15 days')
# Out:
# The above shows the predicted stock price for 15 days

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df[1460:])) ## for the 
plt.plot(Plotarr)
plt.legend(['Orignal Open Price values over the last 6 years','Future Predicted values (15 days)'],loc=2)

# %%
f=pd.DataFrame(pred,columns=['Open'])

# %%
string=bank+'Data'
dfnew=pd.read_csv(string)

# %%
dfnew['Open']=pred

# %%
dfnew.to_csv(string,index=False)

# %%
test=pd.read_csv(string)
