# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_datareader import data, wb
import datetime
import tensorflow as tf
from datetime import date, timedelta
# %matplotlib inline

# %%
start = datetime.datetime(2005, 1, 1)
end = datetime.datetime(2020, 1, 1)

# %%
bank="C"
stocks = data.DataReader(bank, 'yahoo', start, end)

# %%
stocks.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2004-12-31  483.299988  480.000000  481.299988  481.799988   547410.0
# 2005-01-03  490.000000  482.000000  490.000000  482.700012  1474660.0
# 2005-01-04  487.700012  477.000000  482.799988  478.600006  1584770.0
# 2005-01-05  487.799988  480.200012  480.500000  484.600006  1893350.0
# 2005-01-06  492.399994  487.399994  488.000000  489.299988  1804990.0
#
#              Adj Close
# Date
# 2004-12-31  340.349487
# 2005-01-03  340.985321
# 2005-01-04  338.088989
# 2005-01-05  342.327484
# 2005-01-06  345.647644

# %%
plt.figure(figsize=(14,14))
plt.plot(stocks['Open'])
plt.title('Historical Stock Value')
plt.xlabel('Years')
plt.ylabel('Opening Stock Price')
# Out:
# Text(0, 0.5, 'Opening Stock Price')

# %%
df=stocks.reset_index()['Open']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
train_size=int(len(df)*0.70)
test_size=len(df)-train_size
train_data=df[0:train_size]
test_data=df[train_size:]

# %%
def make_dataset(data,timestep):
    X=[]
    y=[]
    n=len(data)
    for i in range(0,n-timestep-1):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X),np.array(y)

# %%
timestep=40
X_train,y_train=make_dataset(train_data,timestep)
X_test,y_test=make_dataset(test_data,timestep)
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(40,return_sequences=True,input_shape=(timestep,1)))
model.add(LSTM(40,return_sequences=True))
model.add(LSTM(40))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam') ##Stacked LSTM

# %%
import numpy as np
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional
from keras.datasets import imdb

# %%
modelBD = Sequential()
modelBD.add(Bidirectional(LSTM(64)))
modelBD.add(Dropout(0.5))
modelBD.add(Dense(1,activation='sigmoid'))
modelBD.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy']) ## Creating Bi-Directional LSTM

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 40, 40)            6720
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 40, 40)            12960
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 40)                12960
# _________________________________________________________________
# dense (Dense)                (None, 1)                 41
# =================================================================
# Total params: 32,681
# Trainable params: 32,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=70,batch_size=40,verbose=1)
# Out:
# Epoch 1/70
# 66/66 [==============================] - 6s 45ms/step - loss: 0.0199 - val_loss: 1.8233e-04
# Epoch 2/70
# 66/66 [==============================] - 2s 32ms/step - loss: 5.4414e-04 - val_loss: 3.7128e-05
# Epoch 3/70
# 66/66 [==============================] - 2s 33ms/step - loss: 4.8218e-04 - val_loss: 5.6043e-05
# Epoch 4/70
# 66/66 [==============================] - 2s 33ms/step - loss: 4.3514e-04 - val_loss: 3.9585e-05
# Epoch 5/70
# 66/66 [==============================] - 2s 34ms/step - loss: 4.2908e-04 - val_loss: 3.5664e-05
# Epoch 6/70
# 66/66 [==============================] - 2s 37ms/step - loss: 4.6606e-04 - val_loss: 4.1620e-05
# Epoch 7/70
# 66/66 [==============================] - 2s 36ms/step - loss: 4.1143e-04 - val_loss: 3.8264e-05
# Epoch 8/70
# Epoch 58/70
# 66/66 [==============================] - 2s 37ms/step - loss: 1.4579e-04 - val_loss: 1.6991e-05
# Epoch 59/70
# 66/66 [==============================] - 3s 39ms/step - loss: 1.4000e-04 - val_loss: 2.0822e-05
# Epoch 60/70
# 66/66 [==============================] - 2s 37ms/step - loss: 1.2818e-04 - val_loss: 1.3143e-05
# Epoch 61/70
# 66/66 [==============================] - 2s 38ms/step - loss: 1.2575e-04 - val_loss: 8.1038e-06
# Epoch 62/70
# 66/66 [==============================] - 2s 38ms/step - loss: 1.2549e-04 - val_loss: 8.5292e-06
# Epoch 63/70
# 66/66 [==============================] - 2s 37ms/step - loss: 1.3091e-04 - val_loss: 7.3849e-06
# Epoch 64/70
# 66/66 [==============================] - 2s 37ms/step - loss: 1.1338e-04 - val_loss: 1.2367e-05
# Epoch 65/70
# 66/66 [==============================] - 2s 38ms/step - loss: 1.0958e-04 - val_loss: 1.3741e-05
# Epoch 66/70
# 66/66 [==============================] - 3s 38ms/step - loss: 1.1616e-04 - val_loss: 1.2697e-05
# Epoch 67/70
# 66/66 [==============================] - 2s 37ms/step - loss: 1.1945e-04 - val_loss: 3.1966e-05
# Epoch 68/70
# 66/66 [==============================] - 2s 37ms/step - loss: 1.0885e-04 - val_loss: 1.0976e-05
# Epoch 69/70
# 66/66 [==============================] - 2s 38ms/step - loss: 1.1016e-04 - val_loss: 7.1046e-05
# Epoch 70/70
# 66/66 [==============================] - 2s 38ms/step - loss: 2.4646e-04 - val_loss: 6.2848e-06

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
train_predict
# Out:
# array([[490.6968  ],
#        [488.60257 ],
#        [485.27274 ],
#        ...,
#        [ 57.18977 ],
#        [ 57.12267 ],
#        [ 56.713585]], dtype=float32)

# %%
test_predict
# Out:
# array([[53.285526],
#        [53.62319 ],
#        [53.916946],
#        ...,
#        [78.066124],
#        [78.17223 ],
#        [78.53854 ]], dtype=float32)

# %%
lookback=timestep
trainPlot=np.empty_like(df)
trainPlot[:,:]=np.nan
trainPlot[lookback:len(train_predict)+lookback, :]=train_predict

testPlot=np.empty_like(df)
testPlot[:, :]=np.nan
testPlot[len(train_predict)+(lookback*2)+1:len(df)-1, :]=test_predict

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPlot)
plt.plot(testPlot,color='g')
plt.title('Graph comparison of predicted values')
plt.xlabel('Number of days')
plt.ylabel('Opening Stock Prices')
plt.legend(['Orginal values','Train predicted values','Test Predicted Values'],loc=2)

# %%
def errorpercentage(y_test,pred):
    mape=np.mean(np.abs(y_test-pred)/y_test*100)
    return mape

# %%
print('Accuracy using Stacked LSTM',100-errorpercentage(scaler.inverse_transform(y_test),test_predict))
# Out:
# Accuracy using Stacked LSTM 98.20132988047416

# %%
a=test_data.shape[0]
x=test_data[a-timestep:]
scaler.inverse_transform(x)
# Out:
# array([[74.94000244],
#        [75.19000244],
#        [74.41999817],
#        [75.41000366],
#        [75.48000336],
#        [75.44999695],
#        [75.55000305],
#        [74.25      ],
#        [73.61000061],
#        [74.33999634],
#        [74.29000092],
#        [74.97000122],
#        [74.62999725],
#        [74.08000183],
#        [74.09999847],
#        [74.93000031],
#        [75.83999634],
#        [75.83999634],
#        [75.43000031],
#        [75.41999817],
#        [73.37999725],
#        [73.83000183],
#        [74.65000153],
#        [75.93000031],
#        [75.18000031],
#        [75.06999969],
#        [76.12000275],
#        [75.80999756],
#        [77.05000305],
#        [77.36000061],
#        [77.29000092],
#        [77.69999695],
#        [78.        ],
#        [78.94000244],
#        [78.66999817],
#        [78.69999695],
#        [78.75      ],
#        [80.        ],
#        [80.15000153],
#        [79.31999969]])

# %%
x.shape
# Out:
# (40, 1)

# %%
pred_stocks = data.DataReader(bank, 'yahoo', end+timedelta(1), end+timedelta(22))## reading data for next 15 days

# %%
pred_stocks
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-01-02  81.260002  80.029999  80.129997  81.230003  12728900  74.407089
# 2020-01-03  80.519997  79.449997  79.800003  79.699997  12437400  73.005608
# 2020-01-06  79.550003  78.720001  78.720001  79.449997  10059500  72.776604
# 2020-01-07  79.300003  78.730003  79.290001  78.760002  10469100  72.144569
# 2020-01-08  80.000000  78.680000  78.769997  79.360001  11292400  72.694176
# 2020-01-09  80.980003  79.730003  80.980003  80.080002  12895900  73.353691
# 2020-01-10  80.010002  79.070000  80.000000  79.250000  10062100  72.593407
# 2020-01-13  80.720001  79.000000  79.500000  80.650002  16566300  73.875816
# 2020-01-14  83.110001  80.970001  81.199997  81.910004  24971800  75.029984
# 2020-01-15  82.050003  80.730003  81.730003  81.239998  16063600  74.416260
# 2020-01-16  82.129997  80.849998  81.959999  81.000000  10426000  74.196419
# 2020-01-17  81.400002  80.809998  81.160004  81.120003  12413100  74.306335
# 2020-01-21  80.910004  79.870003  80.480003  79.900002  10522000  73.188812
# 2020-01-22  80.480003  79.860001  80.199997  80.099998   8045600  73.372017
# 2020-01-23  80.080002  78.919998  79.580002  79.800003  11618200  73.097214

# %%
actual_values=[]
for i in pred_stocks['Open']:
    actual_values.append(i)
actual_values=np.array(actual_values)

# %%
actual_values
# Out:
# array([80.12999725, 79.80000305, 78.72000122, 79.29000092, 78.76999664,
#        80.98000336, 80.        , 79.5       , 81.19999695, 81.73000336,
#        81.95999908, 81.16000366, 80.48000336, 80.19999695, 79.58000183])

# %%
## Prediction for next 15 days
i=0
while(i<15):
    length_of_array=len(x)
    if(length_of_array==timestep):
        temp=x;
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    else:
        temp=x[length_of_array-timestep:]
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    i=i+1

# %%
x=x.reshape(-1,1)
actual_values=actual_values.reshape(-1,1)
scaler.inverse_transform(x[timestep:])
# Out:
# array([[79.13077289],
#        [79.05018011],
#        [78.90939328],
#        [78.78432582],
#        [78.69351297],
#        [78.63461092],
#        [78.59986765],
#        [78.58102596],
#        [78.57078518],
#        [78.56304559],
#        [78.55326033],
#        [78.53868804],
#        [78.5179953 ],
#        [78.49117797],
#        [78.45902285]])

# %%
act,pred=actual_values[:i],scaler.inverse_transform(x[timestep:])

# %%
scaler.inverse_transform(x[timestep:])
# Out:
# array([[79.13077289],
#        [79.05018011],
#        [78.90939328],
#        [78.78432582],
#        [78.69351297],
#        [78.63461092],
#        [78.59986765],
#        [78.58102596],
#        [78.57078518],
#        [78.56304559],
#        [78.55326033],
#        [78.53868804],
#        [78.5179953 ],
#        [78.49117797],
#        [78.45902285]])

# %%
print('Accuracy for Future 15 days values',100-errorpercentage(act,pred))
# Out:
# Accuracy for Future 15 days values 98.03727417337122

# %%
from sklearn.metrics import mean_absolute_error

# %%
print('MSE for future 15 days values',mean_absolute_error(act,pred))
# Out:
# MSE for future 15 days values 1.5867417925708196

# %%
y=len(df)-1460
Plotarr=np.empty([y+15,1])
Plotarr[::]=np.nan
Plotarr[y:]=pred

# %%
pred    ## stocks for the next 15 days
# Out:
# array([[79.13077289],
#        [79.05018011],
#        [78.90939328],
#        [78.78432582],
#        [78.69351297],
#        [78.63461092],
#        [78.59986765],
#        [78.58102596],
#        [78.57078518],
#        [78.56304559],
#        [78.55326033],
#        [78.53868804],
#        [78.5179953 ],
#        [78.49117797],
#        [78.45902285]])

# %%
print('The above shows the predicted stock price for 15 days')
# Out:
# The above shows the predicted stock price for 15 days

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df[1460:])) ## for the 
plt.plot(Plotarr)
plt.legend(['Orignal Open Price values over the last 6 years','Future Predicted values (15 days)'],loc=2)

# %%
f=pd.DataFrame(pred,columns=['Open'])

# %%
string=bank+'Data'
dfnew=pd.read_csv(string)

# %%
dfnew['Open']=pred

# %%
dfnew.to_csv(string,index=False)

# %%
test=pd.read_csv(string)

# %%
dfnew
# Out:
#         Close       Open
# 0   80.165009  79.130773
# 1   80.255973  79.050180
# 2   80.263368  78.909393
# 3   80.284591  78.784326
# 4   80.344396  78.693513
# 5   80.424826  78.634611
# 6   80.506349  78.599868
# 7   80.583234  78.581026
# 8   80.658781  78.570785
# 9   80.737058  78.563046
# 10  80.819533  78.553260
# 11  80.905776  78.538688
# 12  80.995103  78.517995
# 13  81.087343  78.491178
# 14  81.182714  78.459023

# %%
modelBD.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=70,batch_size=40,verbose=1)
# Out:
# Epoch 1/70
# 66/66 [==============================] - 4s 27ms/step - loss: 0.4107 - accuracy: 7.6864e-04 - val_loss: 0.3070 - val_accuracy: 0.0000e+00
# Epoch 2/70
# 66/66 [==============================] - 1s 19ms/step - loss: 0.3145 - accuracy: 7.6864e-04 - val_loss: 0.3079 - val_accuracy: 0.0000e+00
# Epoch 3/70
# 66/66 [==============================] - 1s 20ms/step - loss: 0.3127 - accuracy: 7.6864e-04 - val_loss: 0.3078 - val_accuracy: 0.0000e+00
# Epoch 4/70
# 66/66 [==============================] - 2s 24ms/step - loss: 0.3122 - accuracy: 7.6864e-04 - val_loss: 0.3061 - val_accuracy: 0.0000e+00
# Epoch 5/70
# 66/66 [==============================] - 1s 21ms/step - loss: 0
70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3105 - accuracy: 7.6864e-04 - val_loss: 0.3057 - val_accuracy: 0.0000e+00
# Epoch 50/70
# 66/66 [==============================] - 2s 23ms/step - loss: 0.3102 - accuracy: 7.6864e-04 - val_loss: 0.3060 - val_accuracy: 0.0000e+00
# Epoch 51/70
# 66/66 [==============================] - 2s 23ms/step - loss: 0.3105 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 52/70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3110 - accuracy: 7.6864e-04 - val_loss: 0.3065 - val_accuracy: 0.0000e+00
# Epoch 53/70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3103 - accuracy: 7.6864e-04 - val_loss: 0.3060 - val_accuracy: 0.0000e+00
# Epoch 54/70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3107 - accuracy: 7.6864e-04 - val_loss: 0.3057 - val_accuracy: 0.0000e+00
# Epoch 55/70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3107 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 56/70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3120 - accuracy: 7.6864e-04 - val_loss: 0.3060 - val_accuracy: 0.0000e+00
# Epoch 57/70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3102 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 58/70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3103 - accuracy: 7.6864e-04 - val_loss: 0.3086 - val_accuracy: 0.0000e+00
# Epoch 59/70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3103 - accuracy: 7.6864e-04 - val_loss: 0.3062 - val_accuracy: 0.0000e+00
# Epoch 60/70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3103 - accuracy: 7.6864e-04 - val_loss: 0.3084 - val_accuracy: 0.0000e+00
# Epoch 61/70
# 66/66 [==============================] - 2s 24ms/step - loss: 0.3109 - accuracy: 7.6864e-04 - val_loss: 0.3057 - val_accuracy: 0.0000e+00
# Epoch 62/70
# 66/66 [==============================] - 2s 24ms/step - loss: 0.3102 - accuracy: 7.6864e-04 - val_loss: 0.3059 - val_accuracy: 0.0000e+00
# Epoch 63/70
# 66/66 [==============================] - 2s 24ms/step - loss: 0.3101 - accuracy: 7.6864e-04 - val_loss: 0.3087 - val_accuracy: 0.0000e+00
# Epoch 64/70
# 66/66 [==============================] - 2s 23ms/step - loss: 0.3102 - accuracy: 7.6864e-04 - val_loss: 0.3070 - val_accuracy: 0.0000e+00
# Epoch 65/70
# 66/66 [==============================] - 1s 23ms/step - loss: 0.3101 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 66/70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3101 - accuracy: 7.6864e-04 - val_loss: 0.3057 - val_accuracy: 0.0000e+00
# Epoch 67/70
# 66/66 [==============================] - 1s 22ms/step - loss: 0.3099 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 68/70
# 66/66 [==============================] - 1s 23ms/step - loss: 0.3102 - accuracy: 7.6864e-04 - val_loss: 0.3057 - val_accuracy: 0.0000e+00
# Epoch 69/70
# 66/66 [==============================] - 2s 23ms/step - loss: 0.3100 - accuracy: 7.6864e-04 - val_loss: 0.3059 - val_accuracy: 0.0000e+00
# Epoch 70/70
# 66/66 [==============================] - 2s 23ms/step - loss: 0.3101 - accuracy: 7.6864e-04 - val_loss: 0.3057 - val_accuracy: 0.0000e+00

# %%
train_predict=modelBD.predict(X_train)
test_predict=modelBD.predict(X_test)

# %%
trypredict=scaler.inverse_transform(test_predict)

# %%
trypredict
# Out:
# array([[54.939255],
#        [54.664623],
#        [54.44003 ],
#        ...,
#        [74.5738  ],
#        [74.80776 ],
#        [75.116455]], dtype=float32)

# %%
print('Accuracy using Bi-directional LSTM',100-errorpercentage(scaler.inverse_transform(y_test),trypredict))
# Out:
# Accuracy using Bi-directional LSTM 96.31848578196603
