# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_datareader import data, wb
import datetime
import tensorflow as tf
from datetime import date, timedelta
# %matplotlib inline

# %%
start = datetime.datetime(2005, 1, 1)
end = datetime.datetime(2020, 1, 1)

# %%
bank="C"
stocks = data.DataReader(bank, 'yahoo', start, end)

# %%
stocks.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2004-12-31  483.299988  480.000000  481.299988  481.799988   547410.0
# 2005-01-03  490.000000  482.000000  490.000000  482.700012  1474660.0
# 2005-01-04  487.700012  477.000000  482.799988  478.600006  1584770.0
# 2005-01-05  487.799988  480.200012  480.500000  484.600006  1893350.0
# 2005-01-06  492.399994  487.399994  488.000000  489.299988  1804990.0
#
#              Adj Close
# Date
# 2004-12-31  340.349518
# 2005-01-03  340.985382
# 2005-01-04  338.089020
# 2005-01-05  342.327423
# 2005-01-06  345.647675

# %%
plt.figure(figsize=(14,14))
plt.plot(stocks['Open'])
plt.title('Historical Stock Value')
plt.xlabel('Years')
plt.ylabel('Opening Stock Price')
# Out:
# Text(0, 0.5, 'Opening Stock Price')

# %%
df=stocks.reset_index()['Open']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
train_size=int(len(df)*0.70)
test_size=len(df)-train_size
train_data=df[0:train_size]
test_data=df[train_size:]

# %%
def make_dataset(data,timestep):
    X=[]
    y=[]
    n=len(data)
    for i in range(0,n-timestep-1):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X),np.array(y)

# %%
timestep=40
X_train,y_train=make_dataset(train_data,timestep)
X_test,y_test=make_dataset(test_data,timestep)
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(40,return_sequences=True,input_shape=(timestep,1)))
model.add(LSTM(40,return_sequences=True))
model.add(LSTM(40))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam') ##Stacked LSTM

# %%
import numpy as np
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Bidirectional
from keras.datasets import imdb

# %%
modelBD = Sequential()
modelBD.add(Bidirectional(LSTM(64)))
modelBD.add(Dropout(0.5))
modelBD.add(Dense(1,activation='sigmoid'))
modelBD.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy']) ## Creating Bi-Directional LSTM

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 40, 40)            6720
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 40, 40)            12960
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 40)                12960
# _________________________________________________________________
# dense (Dense)                (None, 1)                 41
# =================================================================
# Total params: 32,681
# Trainable params: 32,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=70,batch_size=40,verbose=1)
# Out:
# Epoch 1/70
# 66/66 [==============================] - 7s 50ms/step - loss: 0.0157 - val_loss: 3.0988e-05
# Epoch 2/70
# 66/66 [==============================] - 2s 34ms/step - loss: 6.4713e-04 - val_loss: 4.4130e-05
# Epoch 3/70
# 66/66 [==============================] - 2s 36ms/step - loss: 5.0451e-04 - val_loss: 5.7259e-05
# Epoch 4/70
# 66/66 [==============================] - 2s 36ms/step - loss: 4.9430e-04 - val_loss: 3.6040e-05
# Epoch 5/70
# 66/66 [==============================] - 2s 37ms/step - loss: 4.6844e-04 - val_loss: 8.7046e-05
# Epoch 6/70
# 66/66 [==============================] - 2s 38ms/step - loss: 4.7937e-04 - val_loss: 1.6633e-04
# Epoch 7/70
# 66/66 [==============================] - 3s 41ms/step - loss: 5.5783e-04 - val_loss: 9.2356e-05
# Epoch 8/70
# 66/66 [==============================] - 3s 44ms/step - loss: 4.8640e-04 - val_loss: 6.9955e-05
# Epoch 9/70
# 66/66 [==============================] - 3s 43ms/step - loss: 3.9246e-04 - val_loss: 2.4268e-05
# Epoch 10/70
# 66/66 [==============================] - 3s 44ms/step - loss: 4.2741e-04 - val_loss: 8.7394e-05
# Epoch 11/70
# 66/66 [==============================] - 3s 43ms/step - loss: 3.8628e-04 - val_loss: 6.3371e-05
# Epoch 12/70
# 66/66 [==============================] - 3s 42ms/step - loss: 3.6966e-04 - val_loss: 8.0696e-05
# Epoch 13/70
# 66/66 [==============================] - 3s 42ms/step - loss: 4.6877e-04 - val_loss: 1.3879e-04
# Epoch 14/70
# 66/66 [==============================] - 3s 41ms/step - loss: 3.8879e-04 - val_loss: 2.1815e-05
# Epoch 15/70
# 66/66 [==============================] - 3s 42ms/step - loss: 3.1555e-04 - val_loss: 5.7297e-05
# Epoch 16/70
# 66/66 [==============================] - 3s 44ms/step - loss: 4.0353e-04 - val_loss: 5.3279e-05
# Epoch 17/70
# 66/66 [==============================] - 3s 47ms/step - loss: 3.5281e-04 - val_loss: 5.3016e-05
# Epoch 18/70
# 66/66 [==============================] - 4s 55ms/step - loss: 3.2973e-04 - val_loss: 1.4535e-04
# Epoch 19/70
# 66/66 [==============================] - 3s 48ms/step - loss: 3.3874e-04 - val_loss: 1.9707e-05
# Epoch 20/70
# 66/66 [==============================] - 3s 42ms/step - loss: 3.8794e-04 - val_loss: 4.2095e-05
# Epoch 21/70
# 66/66 [==============================] - 3s 44ms/step - loss: 3.8878e-04 - val_loss: 1.4651e-04
# Epoch 22/70
# 66/66 [==============================] - 3s 45ms/step - loss: 2.8589e-04 - val_loss: 6.3889e-05
# Epoch 23/70
# 66/66 [==============================] - 3s 41ms/step - loss: 3.5550e-04 - val_loss: 1.6511e-05ss: 3
# Epoch 24/70
# 66/66 [==============================] - 3s 52ms/step - loss: 2.6467e-04 - val_loss: 3.6273e-05
# Epoch 25/70
# 66/66 [==============================] - 3s 52ms/step - loss: 2.6641e-04 - val_loss: 3.3943e-05
# Epoch 26/70
# 66/66 [==============================] - 4s 57ms/step - loss: 2.7643e-04 - val_loss: 6.7253e-05
# Epoch 27/70
# 66/66 [==============================] - 3s 52ms/step - loss: 2.5648e-04 - val_loss: 1.6525e-05
# Epoch 28/70
# 66/66 [==============================] - 4s 58ms/step - loss: 2.5327e-04 - val_loss: 6.5202e-05
# Epoch 29/70
# 66/66 [==============================] - 4s 61ms/step - loss: 2.9826e-04 - val_loss: 1.7625e-05: 0s - loss: 3.05
# Epoch 30/70
# 66/66 [==============================] - 4s 67ms/step - loss: 2.8101e-04 - val_loss: 1.6085e-05
# Epoch 31/70
# 66/66 [==============================] - 4s 63ms/step - loss: 2.8379e-04 - val_loss: 2.0786e-05
# Epoch 32/70
# 66/66 [==============================] - 4s 60ms/step - loss: 3.0151e-04 - val_loss: 3.6608e-05
# Epoch 33/70
# 66/66 [==============================] - 4s 58ms/step - loss: 2.3102e-04 - val_loss: 3.3103e-05
# Epoch 34/70
# 66/66 [==============================] - 4s 60ms/step - loss: 2.2427e-04 - val_loss: 2.3944e-04
# Epoch 35/70
# 66/66 [==============================] - 4s 58ms/step - loss: 5.8533e-04 - val_loss: 1.6128e-05
# Epoch 36/70
# 66/66 [==============================] - 4s 59ms/step - loss: 2.4657e-04 - val_loss: 1.4275e-05
# Epoch 37/70
# 66/66 [==============================] - 4s 57ms/step - loss: 2.2482e-04 - val_loss: 1.4991e-051
# Epoch 38/70
# 66/66 [==============================] - 4s 60ms/step - loss: 2.5820e-04 - val_loss: 1.6360e-05
# Epoch 39/70
# 66/66 [==============================] - 4s 60ms/step - loss: 2.1764e-04 - val_loss: 1.5444e-05
# Epoch 40/70
# 66/66 [==============================] - 4s 63ms/step - loss: 3.0291e-04 - val_loss: 2.0726e-05
# Epoch 41/70
# 66/66 [==============================] - 4s 60ms/step - loss: 2.2347e-04 - val_loss: 1.8447e-05
# Epoch 42/70
# 66/66 [==============================] - 4s 68ms/step - loss: 1.9984e-04 - val_loss: 1.3188e-05
# Epoch 43/70
# 66/66 [==============================] - 4s 64ms/step - loss: 1.9781e-04 - val_loss: 1.3898e-05
# Epoch 44/70
# 66/66 [==============================] - 4s 59ms/step - loss: 2.1352e-04 - val_loss: 6.7242e-05
# Epoch 45/70
# 66/66 [==============================] - 4s 59ms/step - loss: 2.1512e-04 - val_loss: 2.1113e-05
# Epoch 46/70
# 66/66 [==============================] - 4s 61ms/step - loss: 1.8859e-04 - val_loss: 5.0994e-05
# Epoch 47/70
# 66/66 [==============================] - 4s 60ms/step - loss: 2.0416e-04 - val_loss: 1.8201e-05
# Epoch 48/70
# 66/66 [==============================] - 4s 60ms/step - loss: 1.8951e-04 - val_loss: 1.9524e-05
# Epoch 49/70
# 66/66 [==============================] - 4s 57ms/step - loss: 1.8509e-04 - val_loss: 2.2000e-05
# Epoch 50/70
# 66/66 [==============================] - 4s 59ms/step - loss: 1.6782e-04 - val_loss: 5.9619e-05
# Epoch 51/70
# 66/66 [==============================] - 4s 60ms/step - loss: 2.1671e-04 - val_loss: 1.5581e-05
# Epoch 52/70
# 66/66 [==============================] - 4s 60ms/step - loss: 2.0283e-04 - val_loss: 1.9259e-05
# Epoch 53/70
# 66/66 [==============================] - 4s 58ms/step - loss: 2.8919e-04 - val_loss: 1.1210e-05
# Epoch 54/70
# 66/66 [==============================] - 4s 59ms/step - loss: 1.6629e-04 - val_loss: 1.0942e-05
# Epoch 55/70
# 66/66 [==============================] - 4s 59ms/step - loss: 1.6781e-04 - val_loss: 3.7539e-05
# Epoch 56/70
# 66/66 [==============================] - 4s 56ms/step - loss: 1.6938e-04 - val_loss: 1.5115e-05
# Epoch 57/70
# 66/66 [==============================] - 4s 56ms/step - loss: 1.5794e-04 - val_loss: 9.8224e-06
# Epoch 58/70
# 66/66 [==============================] - 4s 56ms/step - loss: 1.5496e-04 - val_loss: 1.0077e-05
# Epoch 59/70
# 66/66 [==============================] - 4s 59ms/step - loss: 1.9126e-04 - val_loss: 1.5030e-05
# Epoch 60/70
# 66/66 [==============================] - 4s 57ms/step - loss: 1.5104e-04 - val_loss: 1.5000e-05
# Epoch 61/70
# 66/66 [==============================] - 4s 56ms/step - loss: 1.3901e-04 - val_loss: 1.1683e-05
# Epoch 62/70
# 66/66 [==============================] - 4s 57ms/step - loss: 1.3980e-04 - val_loss: 2.2102e-05 loss: 1.474
# Epoch 63/70
# 66/66 [==============================] - 4s 60ms/step - loss: 1.2999e-04 - val_loss: 1.4464e-05
# Epoch 64/70
# 66/66 [==============================] - 4s 58ms/step - loss: 1.3595e-04 - val_loss: 1.6169e-05
# Epoch 65/70
# 66/66 [==============================] - 4s 56ms/step - loss: 1.3766e-04 - val_loss: 1.4103e-05
# Epoch 66/70
# 66/66 [==============================] - 4s 56ms/step - loss: 1.2579e-04 - val_loss: 4.8165e-05
# Epoch 67/70
# 66/66 [==============================] - 4s 58ms/step - loss: 2.1810e-04 - val_loss: 9.6546e-06
# Epoch 68/70
# 66/66 [==============================] - 4s 55ms/step - loss: 1.3221e-04 - val_loss: 2.1720e-04
# Epoch 69/70
# 66/66 [==============================] - 4s 56ms/step - loss: 2.6578e-04 - val_loss: 1.9398e-05
# Epoch 70/70
# 66/66 [==============================] - 4s 56ms/step - loss: 1.2023e-04 - val_loss: 7.7703e-06

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
train_predict
# Out:
# array([[485.6072  ],
#        [483.71393 ],
#        [480.67853 ],
#        ...,
#        [ 56.889294],
#        [ 56.857014],
#        [ 56.582275]], dtype=float32)

# %%
test_predict
# Out:
# array([[53.267776],
#        [53.240734],
#        [53.33279 ],
#        ...,
#        [77.41756 ],
#        [77.57884 ],
#        [77.89074 ]], dtype=float32)

# %%
lookback=timestep
trainPlot=np.empty_like(df)
trainPlot[:,:]=np.nan
trainPlot[lookback:len(train_predict)+lookback, :]=train_predict

testPlot=np.empty_like(df)
testPlot[:, :]=np.nan
testPlot[len(train_predict)+(lookback*2)+1:len(df)-1, :]=test_predict

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPlot)
plt.plot(testPlot,color='g')
plt.title('Graph comparison of predicted values')
plt.xlabel('Number of days')
plt.ylabel('Opening Stock Prices')
plt.legend(['Orginal values','Train predicted values','Test Predicted Values'],loc=2)

# %%
def errorpercentage(y_test,pred):
    mape=np.mean(np.abs(y_test-pred)/y_test)*100
    return mape

# %%
print('Accuracy using Stacked LSTM',100-errorpercentage(scaler.inverse_transform(y_test),test_predict))
# Out:
# Accuracy using Stacked LSTM 97.98463364920269

# %%
a=test_data.shape[0]
x=test_data[a-timestep:]
scaler.inverse_transform(x)
# Out:
# array([[74.94000244],
#        [75.19000244],
#        [74.41999817],
#        [75.41000366],
#        [75.48000336],
#        [75.44999695],
#        [75.55000305],
#        [74.25      ],
#        [73.61000061],
#        [74.33999634],
#        [74.29000092],
#        [74.97000122],
#        [74.62999725],
#        [74.08000183],
#        [74.09999847],
#        [74.93000031],
#        [75.83999634],
#        [75.83999634],
#        [75.43000031],
#        [75.41999817],
#        [73.37999725],
#        [73.83000183],
#        [74.65000153],
#        [75.93000031],
#        [75.18000031],
#        [75.06999969],
#        [76.12000275],
#        [75.80999756],
#        [77.05000305],
#        [77.36000061],
#        [77.29000092],
#        [77.69999695],
#        [78.        ],
#        [78.94000244],
#        [78.66999817],
#        [78.69999695],
#        [78.75      ],
#        [80.        ],
#        [80.15000153],
#        [79.31999969]])

# %%
x.shape
# Out:
# (40, 1)

# %%
pred_stocks = data.DataReader(bank, 'yahoo', end+timedelta(1), end+timedelta(22))## reading data for next 15 days

# %%
pred_stocks
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-01-02  81.260002  80.029999  80.129997  81.230003  12728900  74.407112
# 2020-01-03  80.519997  79.449997  79.800003  79.699997  12437400  73.005608
# 2020-01-06  79.550003  78.720001  78.720001  79.449997  10059500  72.776611
# 2020-01-07  79.300003  78.730003  79.290001  78.760002  10469100  72.144569
# 2020-01-08  80.000000  78.680000  78.769997  79.360001  11292400  72.694168
# 2020-01-09  80.980003  79.730003  80.980003  80.080002  12895900  73.353699
# 2020-01-10  80.010002  79.070000  80.000000  79.250000  10062100  72.593414
# 2020-01-13  80.720001  79.000000  79.500000  80.650002  16566300  73.875824
# 2020-01-14  83.110001  80.970001  81.199997  81.910004  24971800  75.029991
# 2020-01-15  82.050003  80.730003  81.730003  81.239998  16063600  74.416252
# 2020-01-16  82.129997  80.849998  81.959999  81.000000  10426000  74.196426
# 2020-01-17  81.400002  80.809998  81.160004  81.120003  12413100  74.306343
# 2020-01-21  80.910004  79.870003  80.480003  79.900002  10522000  73.188812
# 2020-01-22  80.480003  79.860001  80.199997  80.099998   8045600  73.372009
# 2020-01-23  80.080002  78.919998  79.580002  79.800003  11618200  73.097214

# %%
actual_values=[]
for i in pred_stocks['Open']:
    actual_values.append(i)
actual_values=np.array(actual_values)

# %%
actual_values
# Out:
# array([80.12999725, 79.80000305, 78.72000122, 79.29000092, 78.76999664,
#        80.98000336, 80.        , 79.5       , 81.19999695, 81.73000336,
#        81.95999908, 81.16000366, 80.48000336, 80.19999695, 79.58000183])

# %%
## Prediction for next 15 days
i=0
while(i<15):
    length_of_array=len(x)
    if(length_of_array==timestep):
        temp=x;
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    else:
        temp=x[length_of_array-timestep:]
        temp=temp.reshape(1,timestep,1)
        yget=model.predict(temp)
        x=np.append(x,yget)
    i=i+1

# %%
x=x.reshape(-1,1)
actual_values=actual_values.reshape(-1,1)
scaler.inverse_transform(x[timestep:])
# Out:
# array([[78.45255042],
#        [78.36645006],
#        [78.1571747 ],
#        [77.91800521],
#        [77.68620676],
#        [77.47170955],
#        [77.27417401],
#        [77.09036599],
#        [76.91666209],
#        [76.74971222],
#        [76.58679571],
#        [76.42583791],
#        [76.26536875],
#        [76.10453519],
#        [75.94287341]])

# %%
act,pred=actual_values[:i],scaler.inverse_transform(x[timestep:])

# %%
scaler.inverse_transform(x[timestep:])
# Out:
# array([[78.45255042],
#        [78.36645006],
#        [78.1571747 ],
#        [77.91800521],
#        [77.68620676],
#        [77.47170955],
#        [77.27417401],
#        [77.09036599],
#        [76.91666209],
#        [76.74971222],
#        [76.58679571],
#        [76.42583791],
#        [76.26536875],
#        [76.10453519],
#        [75.94287341]])

# %%
print('Accuracy for Future 15 days values',100-errorpercentage(act,pred))
# Out:
# Accuracy for Future 15 days values 96.18979316312219

# %%
from sklearn.metrics import mean_absolute_error

# %%
print('MSE for future 15 days values',mean_absolute_error(act,pred))
# Out:
# MSE for future 15 days values 3.072772375413381

# %%
y=len(df)-1460
Plotarr=np.empty([y+15,1])
Plotarr[::]=np.nan
Plotarr[y:]=pred

# %%
pred    ## stocks for the next 15 days
# Out:
# array([[78.45255042],
#        [78.36645006],
#        [78.1571747 ],
#        [77.91800521],
#        [77.68620676],
#        [77.47170955],
#        [77.27417401],
#        [77.09036599],
#        [76.91666209],
#        [76.74971222],
#        [76.58679571],
#        [76.42583791],
#        [76.26536875],
#        [76.10453519],
#        [75.94287341]])

# %%
print('The above shows the predicted stock price for 15 days')
# Out:
# The above shows the predicted stock price for 15 days

# %%
plt.figure(figsize=(15,15))
plt.plot(scaler.inverse_transform(df[1460:])) ## for the 
plt.plot(Plotarr)
plt.legend(['Orignal Open Price values over the last 6 years','Future Predicted values (15 days)'],loc=2)

# %%
f=pd.DataFrame(pred,columns=['Open'])

# %%
string=bank+'Data'
dfnew=pd.read_csv(string)

# %%
dfnew['Open']=pred

# %%
dfnew.to_csv(string,index=False)

# %%
test=pd.read_csv(string)

# %%
dfnew
# Out:
#         Close       Open
# 0   78.276813  78.452550
# 1   78.230740  78.366450
# 2   78.019989  78.157175
# 3   77.743744  77.918005
# 4   77.458445  77.686207
# 5   77.186352  77.471710
# 6   76.931996  77.274174
# 7   76.693264  77.090366
# 8   76.466393  76.916662
# 9   76.248057  76.749712
# 10  76.035622  76.586796
# 11  75.827248  76.425838
# 12  75.621680  76.265369
# 13  75.418125  76.104535
# 14  75.216222  75.942873

# %%
modelBD.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=70,batch_size=40,verbose=1)
# Out:
# Epoch 1/70
# 66/66 [==============================] - 8s 49ms/step - loss: 0.4168 - accuracy: 7.6864e-04 - val_loss: 0.3131 - val_accuracy: 0.0000e+00
# Epoch 2/70
# 66/66 [==============================] - 2s 33ms/step - loss: 0.3161 - accuracy: 7.6864e-04 - val_loss: 0.3105 - val_accuracy: 0.0000e+00
# Epoch 3/70
# 66/66 [==============================] - 2s 33ms/step - loss: 0.3150 - accuracy: 7.6864e-04 - val_loss: 0.3126 - val_accuracy: 0.0000e+00
# Epoch 4/70
# 66/66 [==============================] - 2s 33ms/step - loss: 0.3133 - accuracy: 7.6864e-04 - val_loss: 0.3062 - val_accuracy: 0.0000e+00
# Epoch 5/70
# 66/66 [==============================] - 2s 32ms/step - loss: 0.3122 - accuracy: 7.6864e-04 - val_loss: 0.3068 - val_accuracy: 0.0000e+00
# Epoch 6/70
# 66/66 [==============================] - 2s 34ms/step - loss: 0.3116 - accuracy: 7.6864e-04 - val_loss: 0.3091 - val_accuracy: 0.0000e+00
# Epoch 7/70
# 66/66 [==============================] - 2s 33ms/step - loss: 0.3120 - accuracy: 7.6864e-04 - val_loss: 0.3070 - val_accuracy: 0.0000e+00
# Epoch 8/70
# 66/66 [==============================] - 2s 33ms/step - loss: 0.3117 - accuracy: 7.6864e-04 - val_loss: 0.3085 - val_accuracy: 0.0000e+00
# Epoch 9/70
# 66/66 [==============================] - 2s 34ms/step - loss: 0.3118 - accuracy: 7.6864e-04 - val_loss: 0.3060 - val_accuracy: 0.0000e+00
# Epoch 10/70
# 66/66 [==============================] - 2s 32ms/step - loss: 0.3120 - accuracy: 7.6864e-04 - val_loss: 0.3062 - val_accuracy: 0.0000e+00
# Epoch 11/70
# 66/66 [==============================] - 2s 26ms/step - loss: 0.3113 - accuracy: 7.6864e-04 - val_loss: 0.3060 - val_accuracy: 0.0000e+00
# Epoch 12/70
# 66/66 [==============================] - 2s 28ms/step - loss: 0.3117 - accuracy: 7.6864e-04 - val_loss: 0.3060 - val_accuracy: 0.0000e+00
# Epoch 13/70
# 66/66 [==============================] - 2s 28ms/step - loss: 0.3110 - accuracy: 7.6864e-04 - val_loss: 0.3062 - val_accuracy: 0.0000e+00
# Epoch 14/70
# 66/66 [==============================] - 2s 25ms/step - loss: 0.3114 - accuracy: 7.6864e-04 - val_loss: 0.3067 - val_accuracy: 0.0000e+00
# Epoch 15/70
# 66/66 [==============================] - 2s 23ms/step - loss: 0.3121 - accuracy: 7.6864e-04 - val_loss: 0.3069 - val_accuracy: 0.0000e+00
# Epoch 16/70
# 66/66 [==============================] - 2s 24ms/step - loss: 0.3111 - accuracy: 7.6864e-04 - val_loss: 0.3097 - val_accuracy: 0.0000e+00
# Epoch 17/70
# 66/66 [==============================] - 2s 27ms/step - loss: 0.3108 - accuracy: 7.6864e-04 - val_loss: 0.3059 - val_accuracy: 0.0000e+00
# Epoch 18/70
# 66/66 [==============================] - 2s 26ms/step - loss: 0.3112 - accuracy: 7.6864e-04 - val_loss: 0.3062 - val_accuracy: 0.0000e+00
# Epoch 19/70
# 66/66 [==============================] - 2s 25ms/step - loss: 0.3110 - accuracy: 7.6864e-04 - val_loss: 0.3062 - val_accuracy: 0.0000e+00
# Epoch 20/70
# 66/66 [==============================] - 2s 25ms/step - loss: 0.3108 - accuracy: 7.6864e-04 - val_loss: 0.3074 - val_accuracy: 0.0000e+00
# Epoch 21/70
# 66/66 [==============================] - 2s 24ms/step - loss: 0.3111 - accuracy: 7.6864e-04 - val_loss: 0.3144 - val_accuracy: 0.0000e+00
# Epoch 22/70
# 66/66 [==============================] - 2s 24ms/step - loss: 0.3113 - accuracy: 7.6864e-04 - val_loss: 0.3068 - val_accuracy: 0.0000e+00
# Epoch 23/70
# 66/66 [==============================] - 2s 25ms/step - loss: 0.3108 - accuracy: 7.6864e-04 - val_loss: 0.3064 - val_accuracy: 0.0000e+00
# Epoch 24/70
# 66/66 [==============================] - 2s 25ms/step - loss: 0.3107 - accuracy: 7.6864e-04 - val_loss: 0.3102 - val_accuracy: 0.0000e+00
# Epoch 25/70
# 66/66 [==============================] - 2s 25ms/step - loss: 0.3151 - accuracy: 7.6864e-04 - val_loss: 0.3063 - val_accuracy: 0.0000e+00
# Epoch 26/70
# 66/66 [==============================] - 2s 30ms/step - loss: 0.3118 - accuracy: 7.6864e-04 - val_loss: 0.3086 - val_accuracy: 0.0000e+00
# Epoch 27/70
# 66/66 [==============================] - 2s 31ms/step - loss: 0.3108 - accuracy: 7.6864e-04 - val_loss: 0.3063 - val_accuracy: 0.0000e+00
# Epoch 28/70
# 66/66 [==============================] - 2s 27ms/step - loss: 0.3110 - accuracy: 7.6864e-04 - val_loss: 0.3059 - val_accuracy: 0.0000e+00
# Epoch 29/70
# 66/66 [==============================] - 2s 38ms/step - loss: 0.3109 - accuracy: 7.6864e-04 - val_loss: 0.3097 - val_accuracy: 0.0000e+00
# Epoch 30/70
# 66/66 [==============================] - 2s 38ms/step - loss: 0.3109 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 31/70
# 66/66 [==============================] - 2s 38ms/step - loss: 0.3111 - accuracy: 7.6864e-04 - val_loss: 0.3087 - val_accuracy: 0.0000e+00
# Epoch 32/70
# 66/66 [==============================] - 2s 37ms/step - loss: 0.3103 - accuracy: 7.6864e-04 - val_loss: 0.3086 - val_accuracy: 0.0000e+00
# Epoch 33/70
# 66/66 [==============================] - 2s 38ms/step - loss: 0.3104 - accuracy: 7.6864e-04 - val_loss: 0.3086 - val_accuracy: 0.0000e+00
# Epoch 34/70
# 66/66 [==============================] - 3s 39ms/step - loss: 0.3105 - accuracy: 7.6864e-04 - val_loss: 0.3069 - val_accuracy: 0.0000e+00
# Epoch 35/70
# 66/66 [==============================] - 3s 39ms/step - loss: 0.3104 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 36/70
# 66/66 [==============================] - 3s 38ms/step - loss: 0.3102 - accuracy: 7.6864e-04 - val_loss: 0.3063 - val_accuracy: 0.0000e+00
# Epoch 37/70
# 66/66 [==============================] - 3s 43ms/step - loss: 0.3104 - accuracy: 7.6864e-04 - val_loss: 0.3062 - val_accuracy: 0.0000e+00
# Epoch 38/70
# 66/66 [==============================] - 3s 38ms/step - loss: 0.3103 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 39/70
# 66/66 [==============================] - 3s 41ms/step - loss: 0.3106 - accuracy: 7.6864e-04 - val_loss: 0.3061 - val_accuracy: 0.0000e+00
# Epoch 40/70
# 66/66 [==============================] - 3s 39ms/step - loss: 0.3104 - accuracy: 7.6864e-04 - val_loss: 0.3084 - val_accuracy: 0.0000e+00
# Epoch 41/70
# 66/66 [==============================] - 3s 44ms/step - loss: 0.3102 - accuracy: 7.6864e-04 - val_loss: 0.3060 - val_accuracy: 0.0000e+00
# Epoch 42/70
# 66/66 [==============================] - 3s 45ms/step - loss: 0.3104 - accuracy: 7.6864e-04 - val_loss: 0.3064 - val_accuracy: 0.0000e+00
# Epoch 43/70
# 66/66 [==============================] - 3s 43ms/step - loss: 0.3103 - accuracy: 7.6864e-04 - val_loss: 0.3083 - val_accuracy: 0.0000e+00
# Epoch 44/70
# 66/66 [==============================] - 3s 41ms/step - loss: 0.3103 - accuracy: 7.6864e-04 - val_loss: 0.3061 - val_accuracy: 0.0000e+00
# Epoch 45/70
# 66/66 [==============================] - 3s 42ms/step - loss: 0.3105 - accuracy: 7.6864e-04 - val_loss: 0.3068 - val_accuracy: 0.0000e+00
# Epoch 46/70
# 66/66 [==============================] - 3s 41ms/step - loss: 0.3102 - accuracy: 7.6864e-04 - val_loss: 0.3057 - val_accuracy: 0.0000e+00
# Epoch 47/70
# 66/66 [==============================] - 3s 40ms/step - loss: 0.3104 - accuracy: 7.6864e-04 - val_loss: 0.3061 - val_accuracy: 0.0000e+00
# Epoch 48/70
# 66/66 [==============================] - 3s 39ms/step - loss: 0.3102 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 49/70
# 66/66 [==============================] - 3s 38ms/step - loss: 0.3104 - accuracy: 7.6864e-04 - val_loss: 0.3067 - val_accuracy: 0.0000e+00
# Epoch 50/70
# 66/66 [==============================] - 3s 38ms/step - loss: 0.3105 - accuracy: 7.6864e-04 - val_loss: 0.3065 - val_accuracy: 0.0000e+00
# Epoch 51/70
# 66/66 [==============================] - 3s 38ms/step - loss: 0.3101 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 52/70
# 66/66 [==============================] - 3s 39ms/step - loss: 0.3100 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 53/70
# 66/66 [==============================] - 3s 42ms/step - loss: 0.3103 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 54/70
# 66/66 [==============================] - 3s 40ms/step - loss: 0.3104 - accuracy: 7.6864e-04 - val_loss: 0.3059 - val_accuracy: 0.0000e+00
# Epoch 55/70
# 66/66 [==============================] - 3s 38ms/step - loss: 0.3101 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 56/70
# 66/66 [==============================] - 3s 39ms/step - loss: 0.3113 - accuracy: 7.6864e-04 - val_loss: 0.3068 - val_accuracy: 0.0000e+00
# Epoch 57/70
# 66/66 [==============================] - 3s 39ms/step - loss: 0.3103 - accuracy: 7.6864e-04 - val_loss: 0.3080 - val_accuracy: 0.0000e+00
# Epoch 58/70
# 66/66 [==============================] - 3s 38ms/step - loss: 0.3104 - accuracy: 7.6864e-04 - val_loss: 0.3069 - val_accuracy: 0.0000e+00
# Epoch 59/70
# 66/66 [==============================] - 3s 41ms/step - loss: 0.3101 - accuracy: 7.6864e-04 - val_loss: 0.3070 - val_accuracy: 0.0000e+00
# Epoch 60/70
# 66/66 [==============================] - 3s 42ms/step - loss: 0.3099 - accuracy: 7.6864e-04 - val_loss: 0.3063 - val_accuracy: 0.0000e+00
# Epoch 61/70
# 66/66 [==============================] - 3s 41ms/step - loss: 0.3100 - accuracy: 7.6864e-04 - val_loss: 0.3076 - val_accuracy: 0.0000e+00
# Epoch 62/70
# 66/66 [==============================] - 3s 38ms/step - loss: 0.3101 - accuracy: 7.6864e-04 - val_loss: 0.3068 - val_accuracy: 0.0000e+00
# Epoch 63/70
# 66/66 [==============================] - 3s 38ms/step - loss: 0.3101 - accuracy: 7.6864e-04 - val_loss: 0.3060 - val_accuracy: 0.0000e+00
# Epoch 64/70
# 66/66 [==============================] - 3s 40ms/step - loss: 0.3099 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 65/70
# 66/66 [==============================] - 3s 39ms/step - loss: 0.3104 - accuracy: 7.6864e-04 - val_loss: 0.3069 - val_accuracy: 0.0000e+00
# Epoch 66/70
# 66/66 [==============================] - 3s 39ms/step - loss: 0.3099 - accuracy: 7.6864e-04 - val_loss: 0.3060 - val_accuracy: 0.0000e+00
# Epoch 67/70
# 66/66 [==============================] - 3s 45ms/step - loss: 0.3101 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 68/70
# 66/66 [==============================] - 3s 47ms/step - loss: 0.3103 - accuracy: 7.6864e-04 - val_loss: 0.3058 - val_accuracy: 0.0000e+00
# Epoch 69/70
# 66/66 [==============================] - 3s 43ms/step - loss: 0.3100 - accuracy: 7.6864e-04 - val_loss: 0.3059 - val_accuracy: 0.0000e+00
# Epoch 70/70
# 66/66 [==============================] - 3s 44ms/step - loss: 0.3098 - accuracy: 7.6864e-04 - val_loss: 0.3059 - val_accuracy: 0.0000e+00

# %%
train_predict=modelBD.predict(X_train)
test_predict=modelBD.predict(X_test)

# %%
trypredict=scaler.inverse_transform(test_predict)

# %%
trypredict
# Out:
# array([[58.859917],
#        [58.614273],
#        [58.41436 ],
#        ...,
#        [76.87473 ],
#        [77.087456],
#        [77.37648 ]], dtype=float32)

# %%
print('Accuracy using Bi-directional LSTM',100-errorpercentage(scaler.inverse_transform(y_test),trypredict))
# Out:
# Accuracy using Bi-directional LSTM 94.31777578335527
